# %% [markdown]
# # Week 2: Parsing, Relation Extration and Open Information Extraction
# ### COMP61332: Text Mining, Department of Computer Science, University of Manchester (Riza Batista-Navarro and Viktor Schlegel)

# %% [markdown]
# In this lab session, you will try out some Python code based on the **spaCy** library (https://spacy.io/) for the NLP tasks discussed in the Week 2 Lecture, as well as an application of NLP (Open Information Extraction or Open IE).
# After this session, you should be able to:
# - apply **part-of-speech (POS) tagging** on text
# - apply **dependency parsing** on text
# - develop rules for **extracting relations** from text
# - develop rules for **extracting Open Information Extraction (Open IE) triples**
# - explore and visualise knowledge extracted by Open IE in the form of a graph (optional)
#
# You are provided with three text files (drawn from https://en.wikipedia.org/wiki/Timeline_of_historic_inventions), each containing a list of inventions (from the 1700s, 1800s and 1900s), that you can use for experimentation.

# %% [markdown]
# ## Preparation of necessary packages

# %%
# Loading
# !pip install spacy==3.0
# !python -m spacy download en_core_web_sm

import spacy
from spacy.lang.en import English
from spacy.pipeline import Sentencizer


import en_core_web_sm

nlp = spacy.load('en_core_web_sm')

from spacy import displacy
# Out:
# Collecting spacy==3.0
#   Downloading spacy-3.0.0-cp38-cp38-macosx_10_9_x86_64.whl (12.4 MB)
#      |████████████████████████████████| 12.4 MB 5.9 MB/s eta 0:00:01
# Collecting pydantic<1.8.0,>=1.7.1
#   Downloading pydantic-1.7.3-cp38-cp38-macosx_10_9_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 19.1 MB/s eta 0:00:01
# Collecting thinc<8.1.0,>=8.0.0
#   Downloading thinc-8.0.1-cp38-cp38-macosx_10_9_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 23.2 MB/s eta 0:00:01
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.5-cp38-cp38-macosx_10_9_x86_64.whl (18 kB)
# Collecting srsly<3.0.0,>=2.4.0
#   Downloading srsly-2.4.0-cp38-cp38-macosx_10_9_x86_64.whl (449 kB)
#      |████████████████████████████████| 449 kB 25.7 MB/s eta 0:00:01
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.5-cp38-cp38-macosx_10_9_x86_64.whl (105 kB)
#      |████████████████████████████████| 105 kB 10.3 MB/s eta 0:00:01
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy==3.0) (2.24.0)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.5-cp38-cp38-macosx_10_9_x86_64.whl (31 kB)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.8/site-packages (from spacy==3.0) (2.11.2)
# Collecting spacy-legacy<3.1.0,>=3.0.0
#   Using cached spacy_legacy-3.0.1-py2.py3-none-any.whl (7.0 kB)
# Collecting pathy
#   Downloading pathy-0.4.0-py3-none-any.whl (36 kB)
# Collecting wasabi<1.1.0,>=0.8.1
#   Using cached wasabi-0.8.2-py3-none-any.whl (23 kB)
# Collecting catalogue<2.1.0,>=2.0.1
#   Using cached catalogue-2.0.1-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.8/site-packages (from spacy==3.0) (49.2.0.post20200714)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy==3.0) (20.4)
# Collecting typer<0.4.0,>=0.3.0
#   Using cached typer-0.3.2-py3-none-any.whl (21 kB)
# Requirement already satisfied: numpy>=1.15.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy==3.0) (1.18.5)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.4-cp38-cp38-macosx_10_9_x86_64.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 27.8 MB/s eta 0:00:01
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy==3.0) (4.47.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.0) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.0) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.0) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy==3.0) (1.1.1)
# Collecting smart-open<4.0.0,>=2.2.0
#   Using cached smart_open-3.0.0.tar.gz (113 kB)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy==3.0) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy==3.0) (2.4.7)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /opt/anaconda3/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy==3.0) (7.1.2)
# Building wheels for collected packages: smart-open
#   Building wheel for smart-open (setup.py) ... done
#   Created wheel for smart-open: filename=smart_open-3.0.0-py3-none-any.whl size=107097 sha256=a948e79d36bcbe58c3671a10fecef744ccb79d79f204c54db2185bcdba085f80
#   Stored in directory: /Users/guohuanjie/Library/Caches/pip/wheels/11/73/9a/f91ac1f1816436b16423617c5be5db048697ff152a9c4346f2
# Successfully built smart-open
# Installing collected packages: pydantic, murmurhash, catalogue, cymem, preshed, srsly, blis, wasabi, thinc, spacy-legacy, smart-open, typer, pathy, spacy
# Successfully installed blis-0.7.4 catalogue-2.0.1 cymem-2.0.5 murmurhash-1.0.5 pathy-0.4.0 preshed-3.0.5 pydantic-1.7.3 smart-open-3.0.0 spacy-3.0.0 spacy-legacy-3.0.1 srsly-2.4.0 thinc-8.0.1 typer-0.3.2 wasabi-0.8.2
# Collecting en-core-web-sm==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl (13.7 MB)
#      |████████████████████████████████| 13.7 MB 15.1 MB/s eta 0:00:01
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from en-core-web-sm==3.0.0) (3.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.24.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.47.0)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (49.2.0.post20200714)
# Requirement already satisfied: pathy in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.11.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.4)
# Requirement already satisfied: numpy>=1.15.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.18.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (20.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2020.6.20)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /opt/anaconda3/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from pathy->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.1.1)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.7)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.0.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# ## File loading

# %% [markdown]
# The function below takes as parameter the path to a file containing plain text.

# %%
import codecs

def load_file(path):
    file_text = ''
    file = codecs.open(path, 'r', encoding = 'utf-8')
    file_lines = file.readlines()
    for line in file_lines:
        # Text cleaning, remove any whitespace lines
        line = line.replace('\n','')
        file_text = file_text + line
    file.close()
    return file_text

# %% [markdown]
# ## Sentence segmentation

# %% [markdown]
# The code below is the same as the one we used in Week 1. Customise the list of sentence delimiters if necessary.

# %%
# Create a new NLP pipeline,. Specifying English as the language of interest so that English models are loaded.
nlp = English()

config = {"punct_chars": ["."]}

# Add the component to the pipeline.
sentencizer = nlp.add_pipe('sentencizer', config=config)

# Load the contents of a text file; change the parameter to use another/your own text file.
text = load_file('1800s.txt')

# The following line applies the pipeline (so far only sentence segmentation) on the given text, and stores the result in doc.
annotations = nlp(text)

# Check the result of sentence segmentation.
sents_list = []
for sent in annotations.sents:
    sents_list.append(sent.text.strip())
    
# Check how many sentences were produced
print('Number of sentences: ', len(sents_list))

print('SENTENCE NO.\tSENTENCE:')
for i, sent in enumerate(sents_list):
    print(i, '\t', sent)
# Out:
# Number of sentences:  103
# SENTENCE NO.	SENTENCE:
# 0 	 Alessandro Volta invents the voltaic pile, an early form of battery in Italy, based on previous works by Luigi Galvani.
# 1 	 Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# 2 	 Richard Trevithick invents the steam locomotive.
# 3 	 Hanaoka Seishū creates tsūsensan, the first modern general anesthetic.
# 4 	 Nicéphore Niépce invents the first internal combustion engine capable of doing useful work.
# 5 	 François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# 6 	 Robert Fulton expands water transportation and trade with the workable steamboat.
# 7 	 Nicolas Appert invents the canning process for food.
# 8 	 Friedrich Koenig invents the first powered printing press, which was also the first to use a cylinder.
# 9 	 William Reid Clanny pioneered the invention of the safety lamp which he improved in later years.
# 10 	 Safety lamps based on Clanny's improved design were used until the adoption of electric lamps.
# 11 	 James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# 12 	 Francis Ronalds builds the first working electric telegraph using electrostatic means.
# 13 	 Robert Stirling invents the Stirling engine.
# 14 	 Baron Karl von Drais invents the dandy horse, an early velocipede and precursor to the modern bicycle.
# 15 	 Marc Isambard Brunel invents the tunnelling shield.
# 16 	 Thomas Blanchard invents the pattern-tracing lathe (actually more like a shaper) and was completed by for the U.S. Ordnance Dept.
# 17 	 The lathe can copy symmetrical shapes and is used for making gun stocks, and later, ax handles.
# 18 	 The lathe's patent is in force for 42 years, the record for any U.S. patent.
# 19 	 Nicéphore Niépce invents Heliography, the first photographic process.
# 20 	 Charles Babbage, considered the "father of the computer", begins building the first programmable mechanical computer.
# 21 	 Johann Wolfgang Döbereiner invents the first lighter.
# 22 	 Johann Nikolaus von Dreyse invents the bolt-action rifle.
# 23 	 William Sturgeon invents the electromagnet.
# 24 	 John Walker invents the friction match.
# 25 	 James Beaumont Neilson develops the hot blast process.
# 26 	 Patrick Bell invents the reaping machine.
# 27 	 Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# 28 	 William Mann invents the compound air compressor.
# 29 	 Edwin Budding invents the lawn mower.
# 30 	 Michael Faraday invents a method of electromagnetic induction.
# 31 	 It would be independently invented by Joseph Henry the following year.
# 32 	 Moritz von Jacobi, a German-born Russian, invents the first practical electric motor.
# 33 	 Joseph Henry invents the electromechanical relay.
# 34 	 Samuel Morse invents Morse code.
# 35 	 Moritz von Jacobi invents Electrotyping.
# 36 	 William Otis invents the steam shovel.
# 37 	 James Nasmyth invents the steam hammer.
# 38 	 Edmond Becquerel invents a method for the photovoltaic effect, effectively producing the first solar cell.
# 39 	 Alexander Bain devises a printing telegraph.
# 40 	 William Robert Grove invents the first fuel cell.
# 41 	 John Bennet Lawes invents superphosphate, the first man-made fertilizer.
# 42 	 Friedrich Gottlob Keller and, independently, Charles Fenerty come up with the wood pulp method of paper production.
# 43 	 Isaac Charles Johnson invents Modern Portland cement.
# 44 	 Henri-Joseph Maus invents the Tunnel boring machine.
# 45 	 Ascanio Sobrero invents Nitroglycerin, the first explosive made that was stronger than black powder.
# 46 	 Jonathan J. Couch invents the pneumatic drill.
# 47 	 Walter Hunt invents the first repeating rifle to use metallic cartridges (of his own design) and a spring-fed magazine.
# 48 	 James B. Francis invents the Francis turbine.
# 49 	 Sir William Armstrong invents the hydraulic accumulator.
# 50 	 Robert Bunsen is the first to use a chemical vapor deposition technique.
# 51 	 Elisha Otis invents the safety brake elevator.
# 52 	 Henri Giffard becomes the first person to make a manned, controlled and powered flight using a dirigible.
# 53 	 François Coignet invents reinforced concrete.
# 54 	 James Clerk Maxwell invents the first practical method for color photography, whether chemical or electronic.
# 55 	 Sir.
# 56 	 Henry Bessemer patents the Bessemer process for making steel, with improvements made by others over the following years.
# 57 	 James Harrison produces the world's first practical ice making machine and refrigerator using the principle of vapour compression in Geelong, Australia.
# 58 	 William Henry Perkin invents Mauveine, the first synthetic dye.
# 59 	 Heinrich Geissler invents the Geissler tube.
# 60 	 Gaston Planté invents the lead acid battery, the first rechargeable battery.
# 61 	 Joseph Swan produces carbon fibers.
# 62 	 Alexander Parkes invents parkesine, also known as celluloid, the first man-made plastic.
# 63 	 Louis Pasteur invents the pasteurization process.
# 64 	 Carl Wilhelm Siemens and Pierre-Émile Martin invented the Siemens-Martin process for making steel.
# 65 	 Gregor Mendel publishes 'Versuche über Pflanzenhybriden' ("Experiments on Plant Hybridization"), effectively founding the science of genetics, though the importance of his work would not be appreciated until later on.
# 66 	 Alfred Nobel invents Dynamite, the first safely manageable explosive stronger than black powder.
# 67 	 Lucien B. Smith invents barbed wire, which Joseph F. Glidden will modify in 1874, leading to the taming of the West and the end of the cowboys.
# 68 	 J.E.T. Woods and J. Clark invented Stainless steel.
# 69 	 Harry Brearley was the first to commercialize it.
# 70 	 Frederick Ransome invents the rotary kiln.
# 71 	 Sir William Crookes, a chemist, invents the Crookes radiometer as the by-product of some chemical research.
# 72 	 Zénobe Gramme invents the first commercial electrical generator, the Gramme machine.
# 73 	 Gustave Trouvé invents the first metal detector.
# 74 	 Nikolaus August Otto invents the Four-stroke cycle.
# 75 	 Alexander Graham Bell has a patent granted for the telephone.
# 76 	 However, other inventors before Bell had worked on the development of the telephone and the invention had several pioneers.
# 77 	 Thomas Edison invents the first working phonograph.
# 78 	 Henry Fleuss is granted a patent for the first practical rebreather.
# 79 	 Lester Allan Pelton invents the Pelton wheel.
# 80 	 Joseph Swan and Thomas Edison both patent a functional Incandescent light bulb.
# 81 	 Some two dozen inventors had experimented with electric incandescent lighting over the first three-quarters of the 19th century but never came up with a practical design.
# 82 	 Swan's, which he had been working on his since the 1860s, had a low resistance so was only suited for small installations.
# 83 	 Edison designed a high-resistance bulb as part of a large-scale commercial electric lighting utility.
# 84 	 Nikolay Benardos presents carbon arc welding, the first practical arc welding method.
# 85 	 Hiram Maxim invents the recoil-operated Maxim gun, ushering in the age of semi- and fully automatic firearms.
# 86 	 Paul Vieille invents Poudre B, the first smokeless powder for firearms.
# 87 	 Sir Charles Parsons invents the modern steam turbine.
# 88 	 Hungarian engineers Károly Zipernowsky, Ottó Bláthy and Miksa Déri intvent the closed core high efficiency transformer and the AC parallel power distribution.
# 89 	 John Kemp Starley invents the modern bicycle.
# 90 	 Carl Gassner invents the zinc-carbon battery, the first dry cell battery, making portable electronics practical.
# 91 	 Charles Martin Hall and independently Paul Héroult invent the Hall–Héroult process for economically producing aluminum in 1886.Karl Benz invents the first petrol or gasoline powered auto-mobile (car).Carl Josef Bayer invents the Bayer process for the production of alumina.
# 92 	 James Blyth invents the first wind turbine used for generating electricity.
# 93 	 John Stewart MacArthur, working in collaboration with brothers Dr. Robert and Dr. William Forrest develops the process of gold cyanidation.
# 94 	 John J. Loud invents the ballpoint pen.
# 95 	 Heinrich Hertz publishes a conclusive proof of James Clerk Maxwell's electromagnetic theory in experiments that also demonstrate the existence of radio waves.
# 96 	 The effects of electromagnetic waves had been observed by many people before this but no usable theory explaining them existed until Maxwell.
# 97 	 Frédéric Swarts invents the first chlorofluorocarbons to be applied as refrigerant.
# 98 	 Clément Ader invents the first aircraft, airplane, fly machine called Eole (aircraft) or Ader ÉoleWhitcomb Judson invents the zipper.
# 99 	 Léon Bouly invents the cinematograph.
# 100 	 Rudolf Diesel invents the diesel engine (although Herbert Akroyd Stuart had experimented with compression ignition before Diesel).Guglielmo Marconi invents a system of wireless communication using radio waves.
# 101 	 Wilhelm Conrad Röntgen invented the first radiograph (xrays).Hans von Pechmann synthesizes polyethylene, now the most common plastic in the world.
# 102 	 Waldemar Jungner invents the nickel– battery.

# %% [markdown]
# ## Dependency parsing (with in-built POS tagging)

# %% [markdown]
# ### One example for easier visualisation/debugging

# %% [markdown]
# The code below applies a dependency parser on a sentence. For each token, the following attributes are printed:
# - token.text (the token text)
# - token.lemma_ (the base form of the token)
# - token.pos_ (the POS tag according to the Universal Dependencies scheme; see https://universaldependencies.org/u/pos/)
# - token.tag_ (the POS tag according to the Penn Treebank; see https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html
# - token_dep_ (the dependency type)
# - child.text:child.dep_ (a list of dependents; the text and dependency type are displayed for each dependent)
#
# Moreoever, a **visualisation** of the tree is displayed, which can be helpful later, when you try to write your own rules.

# %%
# Example 1
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')

doc = nlp("Nicolas Appert invents the canning process for food.")
for token in doc:
    print(token.text + '\t' + token.lemma_ + '\t' + token.pos_ + '\t' + token.tag_ + '\t' + token.dep_ + '\t' + str([child.text + ':' + child.dep_ for child in token.children]))

displacy.render(doc, style='dep', jupyter=True)
# Out:
# Nicolas	Nicolas	PROPN	NNP	compound	[]
# Appert	Appert	PROPN	NNP	nsubj	['Nicolas:compound']
# invents	invent	VERB	VBZ	ROOT	['Appert:nsubj', 'process:dobj', '.:punct']
# the	the	DET	DT	det	[]
# canning	canning	NOUN	NN	compound	[]
# process	process	NOUN	NN	dobj	['the:det', 'canning:compound', 'for:prep']
# for	for	ADP	IN	prep	['food:pobj']
# food	food	NOUN	NN	pobj	[]
# .	.	PUNCT	.	punct	[]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ff9bb4fd64f94e89a919c59c03c88943-0" class="displacy" width="1450" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Nicolas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Appert</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">invents</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">canning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">process</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">food.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ff9bb4fd64f94e89a919c59c03c88943-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ff9bb4fd64f94e89a919c59c03c88943-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ff9bb4fd64f94e89a919c59c03c88943-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ff9bb4fd64f94e89a919c59c03c88943-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ff9bb4fd64f94e89a919c59c03c88943-0-2" stroke-width="2px" d="M595,264.5 C595,89.5 920.0,89.5 920.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ff9bb4fd64f94e89a919c59c03c88943-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ff9bb4fd64f94e89a919c59c03c88943-0-3" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ff9bb4fd64f94e89a919c59c03c88943-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,266.5 L762,254.5 778,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ff9bb4fd64f94e89a919c59c03c88943-0-4" stroke-width="2px" d="M420,264.5 C420,2.0 925.0,2.0 925.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ff9bb4fd64f94e89a919c59c03c88943-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,266.5 L933.0,254.5 917.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ff9bb4fd64f94e89a919c59c03c88943-0-5" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ff9bb4fd64f94e89a919c59c03c88943-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1090.0,266.5 L1098.0,254.5 1082.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ff9bb4fd64f94e89a919c59c03c88943-0-6" stroke-width="2px" d="M1120,264.5 C1120,177.0 1265.0,177.0 1265.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ff9bb4fd64f94e89a919c59c03c88943-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1265.0,266.5 L1273.0,254.5 1257.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ### <font color='red'>Below, write down any observations you have based on the results of dependency parsing. For example, what kind of dependencies should you follow if you want to reach names of inventors or inventions from the main verb of a sentence?</font>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## Relation extraction

# %% [markdown]
# ### Extracting relations using rules that process the results of dependency parsing

# %% [markdown]
# The code below uses very basic rules to extract **inventor-invention relations**.

# %%
# Create a class that will store every inventor-invention relation that we extract
class Relation:
    inventor = ''
    invention = ''

# %%
relations = []

for sent in sents_list:
    doc = nlp(sent)
    for token in doc:
        # For now, check if the root of the tree is a verb that is a variant of "invent"
        if token.dep_ == 'ROOT' and token.lemma_ == 'invent':
            r = Relation()
            dependents = token.children
            for d in dependents:
                if d.dep_ == 'dobj':
                    r.invention = d.text
                elif d.dep_ == 'nsubj':
                    r.inventor = d.text
            if r.inventor != '' and r.invention != '':
                print('Sentence:', sent)
                print(r.inventor, '-', r.invention)
                relations.append(r)

for r in relations:
    print(r.inventor, '-', r.invention)
# Out:
# Sentence: Alessandro Volta invents the voltaic pile, an early form of battery in Italy, based on previous works by Luigi Galvani.
# Volta - pile
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Davy - lamp
# Sentence: Richard Trevithick invents the steam locomotive.
# Trevithick - locomotive
# Sentence: Nicéphore Niépce invents the first internal combustion engine capable of doing useful work.
# Niépce - engine
# Sentence: Nicolas Appert invents the canning process for food.
# Appert - process
# Sentence: Friedrich Koenig invents the first powered printing press, which was also the first to use a cylinder.
# Koenig - press
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# Fox - machine
# Sentence: Robert Stirling invents the Stirling engine.
# Stirling - engine
# Sentence: Baron Karl von Drais invents the dandy horse, an early velocipede and precursor to the modern bicycle.
# Drais - horse
# Sentence: Marc Isambard Brunel invents the tunnelling shield.
# Brunel - shield
# Sentence: Thomas Blanchard invents the pattern-tracing lathe (actually more like a shaper) and was completed by for the U.S. Ordnance Dept.
# Blanchard - lathe
# Sentence: Nicéphore Niépce invents Heliography, the first photographic process.
# Niépce - Heliography
# Sentence: Johann Wolfgang Döbereiner invents the first lighter.
# Döbereiner - lighter
# Sentence: Johann Nikolaus von Dreyse invents the bolt-action rifle.
# Dreyse - rifle
# Sentence: William Sturgeon invents the electromagnet.
# Sturgeon - electromagnet
# Sentence: John Walker invents the friction match.
# Walker - match
# Sentence: Patrick Bell invents the reaping machine.
# Bell - machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Jedlik - machine
# Sentence: William Mann invents the compound air compressor.
# Mann - compressor
# Sentence: Edwin Budding invents the lawn mower.
# Budding - mower
# Sentence: Michael Faraday invents a method of electromagnetic induction.
# Faraday - method
# Sentence: Moritz von Jacobi, a German-born Russian, invents the first practical electric motor.
# Jacobi - motor
# Sentence: Joseph Henry invents the electromechanical relay.
# Henry - relay
# Sentence: Samuel Morse invents Morse code.
# Morse - code
# Sentence: William Otis invents the steam shovel.
# Otis - shovel
# Sentence: James Nasmyth invents the steam hammer.
# Nasmyth - hammer
# Sentence: Edmond Becquerel invents a method for the photovoltaic effect, effectively producing the first solar cell.
# Becquerel - method
# Sentence: William Robert Grove invents the first fuel cell.
# Grove - cell
# Sentence: Isaac Charles Johnson invents Modern Portland cement.
# Johnson - cement
# Sentence: Henri-Joseph Maus invents the Tunnel boring machine.
# Maus - machine
# Sentence: Jonathan J. Couch invents the pneumatic drill.
# Couch - drill
# Sentence: Walter Hunt invents the first repeating rifle to use metallic cartridges (of his own design) and a spring-fed magazine.
# Hunt - rifle
# Sentence: James B. Francis invents the Francis turbine.
# Francis - turbine
# Sentence: Sir William Armstrong invents the hydraulic accumulator.
# Armstrong - accumulator
# Sentence: Elisha Otis invents the safety brake elevator.
# Otis - elevator
# Sentence: James Clerk Maxwell invents the first practical method for color photography, whether chemical or electronic.
# Maxwell - method
# Sentence: William Henry Perkin invents Mauveine, the first synthetic dye.
# Perkin - Mauveine
# Sentence: Heinrich Geissler invents the Geissler tube.
# Geissler - tube
# Sentence: Gaston Planté invents the lead acid battery, the first rechargeable battery.
# Planté - battery
# Sentence: Louis Pasteur invents the pasteurization process.
# Pasteur - process
# Sentence: Carl Wilhelm Siemens and Pierre-Émile Martin invented the Siemens-Martin process for making steel.
# Martin - process
# Sentence: Alfred Nobel invents Dynamite, the first safely manageable explosive stronger than black powder.
# Nobel - Dynamite
# Sentence: Lucien B. Smith invents barbed wire, which Joseph F. Glidden will modify in 1874, leading to the taming of the West and the end of the cowboys.
# Smith - wire
# Sentence: J.E.T. Woods and J. Clark invented Stainless steel.
# Woods - steel
# Sentence: Frederick Ransome invents the rotary kiln.
# Ransome - kiln
# Sentence: Sir William Crookes, a chemist, invents the Crookes radiometer as the by-product of some chemical research.
# Crookes - radiometer
# Sentence: Zénobe Gramme invents the first commercial electrical generator, the Gramme machine.
# Gramme - generator
# Sentence: Nikolaus August Otto invents the Four-stroke cycle.
# Otto - cycle
# Sentence: Thomas Edison invents the first working phonograph.
# Edison - phonograph
# Sentence: Lester Allan Pelton invents the Pelton wheel.
# Pelton - wheel
# Sentence: Hiram Maxim invents the recoil-operated Maxim gun, ushering in the age of semi- and fully automatic firearms.
# Maxim - gun
# Sentence: Paul Vieille invents Poudre B, the first smokeless powder for firearms.
# Vieille - B
# Sentence: Sir Charles Parsons invents the modern steam turbine.
# Parsons - turbine
# Sentence: John Kemp Starley invents the modern bicycle.
# Starley - bicycle
# Sentence: Carl Gassner invents the zinc-carbon battery, the first dry cell battery, making portable electronics practical.
# Gassner - battery
# Sentence: Charles Martin Hall and independently Paul Héroult invent the Hall–Héroult process for economically producing aluminum in 1886.Karl Benz invents the first petrol or gasoline powered auto-mobile (car).Carl Josef Bayer invents the Bayer process for the production of alumina.
# Hall - Hall
# Sentence: James Blyth invents the first wind turbine used for generating electricity.
# Blyth - turbine
# Sentence: John J. Loud invents the ballpoint pen.
# Loud - pen
# Sentence: Frédéric Swarts invents the first chlorofluorocarbons to be applied as refrigerant.
# Swarts - chlorofluorocarbons
# Sentence: Clément Ader invents the first aircraft, airplane, fly machine called Eole (aircraft) or Ader ÉoleWhitcomb Judson invents the zipper.
# Ader - aircraft
# Sentence: Léon Bouly invents the cinematograph.
# Bouly - cinematograph
# Sentence: Rudolf Diesel invents the diesel engine (although Herbert Akroyd Stuart had experimented with compression ignition before Diesel).Guglielmo Marconi invents a system of wireless communication using radio waves.
# Diesel - engine
# Sentence: Wilhelm Conrad Röntgen invented the first radiograph (xrays).Hans von Pechmann synthesizes polyethylene, now the most common plastic in the world.
# Röntgen - radiograph
# Sentence: Waldemar Jungner invents the nickel– battery.
# Jungner - nickel
# Volta - pile
# Davy - lamp
# Trevithick - locomotive
# Niépce - engine
# Appert - process
# Koenig - press
# Fox - machine
# Stirling - engine
# Drais - horse
# Brunel - shield
# Blanchard - lathe
# Niépce - Heliography
# Döbereiner - lighter
# Dreyse - rifle
# Sturgeon - electromagnet
# Walker - match
# Bell - machine
# Jedlik - machine
# Mann - compressor
# Budding - mower
# Faraday - method
# Jacobi - motor
# Henry - relay
# Morse - code
# Otis - shovel
# Nasmyth - hammer
# Becquerel - method
# Grove - cell
# Johnson - cement
# Maus - machine
# Couch - drill
# Hunt - rifle
# Francis - turbine
# Armstrong - accumulator
# Otis - elevator
# Maxwell - method
# Perkin - Mauveine
# Geissler - tube
# Planté - battery
# Pasteur - process
# Martin - process
# Nobel - Dynamite
# Smith - wire
# Woods - steel
# Ransome - kiln
# Crookes - radiometer
# Gramme - generator
# Otto - cycle
# Edison - phonograph
# Pelton - wheel
# Maxim - gun
# Vieille - B
# Parsons - turbine
# Starley - bicycle
# Gassner - battery
# Hall - Hall
# Blyth - turbine
# Loud - pen
# Swarts - chlorofluorocarbons
# Ader - aircraft
# Bouly - cinematograph
# Diesel - engine
# Röntgen - radiograph
# Jungner - nickel

# %% [markdown]
# ### <font color='red'>The code below is the same as the one above. How will you extend the rules in order to improve the extracted relations? For example: (1) how can you handle verbs that are synonymous to "invent"? (2) How will you handle sentences written in the passive voice, e.g., "X was invented by Y"? </font>
# ### <font color='red'>You can test your idea and code using the above sample code "Example 1" with the sentence "The canning process for food was invented by Nicolas Appert.".</font>

# %%
relations = []

for sent in sents_list:
    doc = nlp(sent)
    for token in doc:
        # For now, check if the root of the tree is a verb that is a variant of "invent"
        if token.dep_ == 'ROOT' and token.lemma_ == 'invent':
            r = Relation()
            dependents = token.children
            for d in dependents:
                if d.dep_ == 'dobj':
                    r.invention = d.text
                elif d.dep_ == 'nsubj':
                    r.inventor = d.text
            if r.inventor != '' and r.invention != '':
                print('Sentence:', sent)
                print(r.inventor, '-', r.invention)
                relations.append(r)

for r in relations:
    print(r.inventor, '-', r.invention)
# Out:
# Sentence: Alessandro Volta invents the voltaic pile, an early form of battery in Italy, based on previous works by Luigi Galvani.
# Volta - pile
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Davy - lamp
# Sentence: Richard Trevithick invents the steam locomotive.
# Trevithick - locomotive
# Sentence: Nicéphore Niépce invents the first internal combustion engine capable of doing useful work.
# Niépce - engine
# Sentence: Nicolas Appert invents the canning process for food.
# Appert - process
# Sentence: Friedrich Koenig invents the first powered printing press, which was also the first to use a cylinder.
# Koenig - press
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# Fox - machine
# Sentence: Robert Stirling invents the Stirling engine.
# Stirling - engine
# Sentence: Baron Karl von Drais invents the dandy horse, an early velocipede and precursor to the modern bicycle.
# Drais - horse
# Sentence: Marc Isambard Brunel invents the tunnelling shield.
# Brunel - shield
# Sentence: Thomas Blanchard invents the pattern-tracing lathe (actually more like a shaper) and was completed by for the U.S. Ordnance Dept.
# Blanchard - lathe
# Sentence: Nicéphore Niépce invents Heliography, the first photographic process.
# Niépce - Heliography
# Sentence: Johann Wolfgang Döbereiner invents the first lighter.
# Döbereiner - lighter
# Sentence: Johann Nikolaus von Dreyse invents the bolt-action rifle.
# Dreyse - rifle
# Sentence: William Sturgeon invents the electromagnet.
# Sturgeon - electromagnet
# Sentence: John Walker invents the friction match.
# Walker - match
# Sentence: Patrick Bell invents the reaping machine.
# Bell - machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Jedlik - machine
# Sentence: William Mann invents the compound air compressor.
# Mann - compressor
# Sentence: Edwin Budding invents the lawn mower.
# Budding - mower
# Sentence: Michael Faraday invents a method of electromagnetic induction.
# Faraday - method
# Sentence: Moritz von Jacobi, a German-born Russian, invents the first practical electric motor.
# Jacobi - motor
# Sentence: Joseph Henry invents the electromechanical relay.
# Henry - relay
# Sentence: Samuel Morse invents Morse code.
# Morse - code
# Sentence: William Otis invents the steam shovel.
# Otis - shovel
# Sentence: James Nasmyth invents the steam hammer.
# Nasmyth - hammer
# Sentence: Edmond Becquerel invents a method for the photovoltaic effect, effectively producing the first solar cell.
# Becquerel - method
# Sentence: William Robert Grove invents the first fuel cell.
# Grove - cell
# Sentence: Isaac Charles Johnson invents Modern Portland cement.
# Johnson - cement
# Sentence: Henri-Joseph Maus invents the Tunnel boring machine.
# Maus - machine
# Sentence: Jonathan J. Couch invents the pneumatic drill.
# Couch - drill
# Sentence: Walter Hunt invents the first repeating rifle to use metallic cartridges (of his own design) and a spring-fed magazine.
# Hunt - rifle
# Sentence: James B. Francis invents the Francis turbine.
# Francis - turbine
# Sentence: Sir William Armstrong invents the hydraulic accumulator.
# Armstrong - accumulator
# Sentence: Elisha Otis invents the safety brake elevator.
# Otis - elevator
# Sentence: James Clerk Maxwell invents the first practical method for color photography, whether chemical or electronic.
# Maxwell - method
# Sentence: William Henry Perkin invents Mauveine, the first synthetic dye.
# Perkin - Mauveine
# Sentence: Heinrich Geissler invents the Geissler tube.
# Geissler - tube
# Sentence: Gaston Planté invents the lead acid battery, the first rechargeable battery.
# Planté - battery
# Sentence: Louis Pasteur invents the pasteurization process.
# Pasteur - process
# Sentence: Carl Wilhelm Siemens and Pierre-Émile Martin invented the Siemens-Martin process for making steel.
# Martin - process
# Sentence: Alfred Nobel invents Dynamite, the first safely manageable explosive stronger than black powder.
# Nobel - Dynamite
# Sentence: Lucien B. Smith invents barbed wire, which Joseph F. Glidden will modify in 1874, leading to the taming of the West and the end of the cowboys.
# Smith - wire
# Sentence: J.E.T. Woods and J. Clark invented Stainless steel.
# Woods - steel
# Sentence: Frederick Ransome invents the rotary kiln.
# Ransome - kiln
# Sentence: Sir William Crookes, a chemist, invents the Crookes radiometer as the by-product of some chemical research.
# Crookes - radiometer
# Sentence: Zénobe Gramme invents the first commercial electrical generator, the Gramme machine.
# Gramme - generator
# Sentence: Nikolaus August Otto invents the Four-stroke cycle.
# Otto - cycle
# Sentence: Thomas Edison invents the first working phonograph.
# Edison - phonograph
# Sentence: Lester Allan Pelton invents the Pelton wheel.
# Pelton - wheel
# Sentence: Hiram Maxim invents the recoil-operated Maxim gun, ushering in the age of semi- and fully automatic firearms.
# Maxim - gun
# Sentence: Paul Vieille invents Poudre B, the first smokeless powder for firearms.
# Vieille - B
# Sentence: Sir Charles Parsons invents the modern steam turbine.
# Parsons - turbine
# Sentence: John Kemp Starley invents the modern bicycle.
# Starley - bicycle
# Sentence: Carl Gassner invents the zinc-carbon battery, the first dry cell battery, making portable electronics practical.
# Gassner - battery
# Sentence: Charles Martin Hall and independently Paul Héroult invent the Hall–Héroult process for economically producing aluminum in 1886.Karl Benz invents the first petrol or gasoline powered auto-mobile (car).Carl Josef Bayer invents the Bayer process for the production of alumina.
# Hall - Hall
# Sentence: James Blyth invents the first wind turbine used for generating electricity.
# Blyth - turbine
# Sentence: John J. Loud invents the ballpoint pen.
# Loud - pen
# Sentence: Frédéric Swarts invents the first chlorofluorocarbons to be applied as refrigerant.
# Swarts - chlorofluorocarbons
# Sentence: Clément Ader invents the first aircraft, airplane, fly machine called Eole (aircraft) or Ader ÉoleWhitcomb Judson invents the zipper.
# Ader - aircraft
# Sentence: Léon Bouly invents the cinematograph.
# Bouly - cinematograph
# Sentence: Rudolf Diesel invents the diesel engine (although Herbert Akroyd Stuart had experimented with compression ignition before Diesel).Guglielmo Marconi invents a system of wireless communication using radio waves.
# Diesel - engine
# Sentence: Wilhelm Conrad Röntgen invented the first radiograph (xrays).Hans von Pechmann synthesizes polyethylene, now the most common plastic in the world.
# Röntgen - radiograph
# Sentence: Waldemar Jungner invents the nickel– battery.
# Jungner - nickel
# Volta - pile
# Davy - lamp
# Trevithick - locomotive
# Niépce - engine
# Appert - process
# Koenig - press
# Fox - machine
# Stirling - engine
# Drais - horse
# Brunel - shield
# Blanchard - lathe
# Niépce - Heliography
# Döbereiner - lighter
# Dreyse - rifle
# Sturgeon - electromagnet
# Walker - match
# Bell - machine
# Jedlik - machine
# Mann - compressor
# Budding - mower
# Faraday - method
# Jacobi - motor
# Henry - relay
# Morse - code
# Otis - shovel
# Nasmyth - hammer
# Becquerel - method
# Grove - cell
# Johnson - cement
# Maus - machine
# Couch - drill
# Hunt - rifle
# Francis - turbine
# Armstrong - accumulator
# Otis - elevator
# Maxwell - method
# Perkin - Mauveine
# Geissler - tube
# Planté - battery
# Pasteur - process
# Martin - process
# Nobel - Dynamite
# Smith - wire
# Woods - steel
# Ransome - kiln
# Crookes - radiometer
# Gramme - generator
# Otto - cycle
# Edison - phonograph
# Pelton - wheel
# Maxim - gun
# Vieille - B
# Parsons - turbine
# Starley - bicycle
# Gassner - battery
# Hall - Hall
# Blyth - turbine
# Loud - pen
# Swarts - chlorofluorocarbons
# Ader - aircraft
# Bouly - cinematograph
# Diesel - engine
# Röntgen - radiograph
# Jungner - nickel

# %% [markdown]
# ### <font color='red'>Summarise below how you extended the code above to improve the extracted relations. In writing your new rules, what other verbs and/or sentence constructions did you consider?</font>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## Open Information Extraction

# %% [markdown]
# ### Adapting the code above to generate ARG1-PREDICATE-ARG2 triples instead of relations

# %% [markdown]
# We can easily adapt the relation extracted code above to extract **ARG1-PREDICATE-ARG2 triples** (for Open Information Extraction) instead of relations. Note that for Open IE, we are interested in any kind of triples (not just those pertaining to inventors and their inventions).

# %%
# Example 2
# Create a class that will store every ARG1-PREDICATE-ARG2 triple that we extract
class Triple:
    arg1 = ''
    predicate = ''
    arg2 = ''

# %%
triples = []

for sent in sents_list:
    doc = nlp(sent)
    for token in doc:
        # For now, assume that the root of the tree is the predicate
        if token.dep_ == 'ROOT':
            t = Triple()
            # Store the lemmatised form (to normalise)
            t.predicate = token.lemma_
            dependents = token.children
            for d in dependents:
                if d.dep_ == 'dobj':
                    t.arg2 = d.text
                elif d.dep_ == 'nsubj':
                    t.arg1 = d.text
            if t.arg1 != '' and t.arg2 != '':
                print('Sentence:', sent)
                print(t.arg1, '-', t.predicate, '-', t.arg2)
                triples.append(t)

for t in triples:
    print(t.arg1, '-', t.predicate, '-', t.arg2)
# Out:
# Sentence: Alessandro Volta invents the voltaic pile, an early form of battery in Italy, based on previous works by Luigi Galvani.
# Volta - invent - pile
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Davy - invent - lamp
# Sentence: Richard Trevithick invents the steam locomotive.
# Trevithick - invent - locomotive
# Sentence: Hanaoka Seishū creates tsūsensan, the first modern general anesthetic.
# Seishū - create - anesthetic
# Sentence: Nicéphore Niépce invents the first internal combustion engine capable of doing useful work.
# Niépce - invent - engine
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# Rivaz - design - automobile
# Sentence: Robert Fulton expands water transportation and trade with the workable steamboat.
# Fulton - expand - transportation
# Sentence: Nicolas Appert invents the canning process for food.
# Appert - invent - process
# Sentence: Friedrich Koenig invents the first powered printing press, which was also the first to use a cylinder.
# Koenig - invent - press
# Sentence: William Reid Clanny pioneered the invention of the safety lamp which he improved in later years.
# Clanny - pioneer - invention
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# Fox - invent - machine
# Sentence: Francis Ronalds builds the first working electric telegraph using electrostatic means.
# Ronalds - build - telegraph
# Sentence: Robert Stirling invents the Stirling engine.
# Stirling - invent - engine
# Sentence: Baron Karl von Drais invents the dandy horse, an early velocipede and precursor to the modern bicycle.
# Drais - invent - horse
# Sentence: Marc Isambard Brunel invents the tunnelling shield.
# Brunel - invent - shield
# Sentence: Thomas Blanchard invents the pattern-tracing lathe (actually more like a shaper) and was completed by for the U.S. Ordnance Dept.
# Blanchard - invent - lathe
# Sentence: The lathe can copy symmetrical shapes and is used for making gun stocks, and later, ax handles.
# lathe - copy - shapes
# Sentence: Nicéphore Niépce invents Heliography, the first photographic process.
# Niépce - invent - Heliography
# Sentence: Johann Wolfgang Döbereiner invents the first lighter.
# Döbereiner - invent - lighter
# Sentence: Johann Nikolaus von Dreyse invents the bolt-action rifle.
# Dreyse - invent - rifle
# Sentence: William Sturgeon invents the electromagnet.
# Sturgeon - invent - electromagnet
# Sentence: John Walker invents the friction match.
# Walker - invent - match
# Sentence: James Beaumont Neilson develops the hot blast process.
# Neilson - develop - process
# Sentence: Patrick Bell invents the reaping machine.
# Bell - invent - machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Jedlik - invent - machine
# Sentence: William Mann invents the compound air compressor.
# Mann - invent - compressor
# Sentence: Edwin Budding invents the lawn mower.
# Budding - invent - mower
# Sentence: Michael Faraday invents a method of electromagnetic induction.
# Faraday - invent - method
# Sentence: Moritz von Jacobi, a German-born Russian, invents the first practical electric motor.
# Jacobi - invent - motor
# Sentence: Joseph Henry invents the electromechanical relay.
# Henry - invent - relay
# Sentence: Samuel Morse invents Morse code.
# Morse - invent - code
# Sentence: William Otis invents the steam shovel.
# Otis - invent - shovel
# Sentence: James Nasmyth invents the steam hammer.
# Nasmyth - invent - hammer
# Sentence: Edmond Becquerel invents a method for the photovoltaic effect, effectively producing the first solar cell.
# Becquerel - invent - method
# Sentence: Alexander Bain devises a printing telegraph.
# Bain - devise - telegraph
# Sentence: William Robert Grove invents the first fuel cell.
# Grove - invent - cell
# Sentence: John Bennet Lawes invents superphosphate, the first man-made fertilizer.
# invents - superphosphate - fertilizer
# Sentence: Isaac Charles Johnson invents Modern Portland cement.
# Johnson - invent - cement
# Sentence: Henri-Joseph Maus invents the Tunnel boring machine.
# Maus - invent - machine
# Sentence: Jonathan J. Couch invents the pneumatic drill.
# Couch - invent - drill
# Sentence: Walter Hunt invents the first repeating rifle to use metallic cartridges (of his own design) and a spring-fed magazine.
# Hunt - invent - rifle
# Sentence: James B. Francis invents the Francis turbine.
# Francis - invent - turbine
# Sentence: Sir William Armstrong invents the hydraulic accumulator.
# Armstrong - invent - accumulator
# Sentence: Elisha Otis invents the safety brake elevator.
# Otis - invent - elevator
# Sentence: François Coignet invents reinforced concrete.
# invents - reinforce - concrete
# Sentence: James Clerk Maxwell invents the first practical method for color photography, whether chemical or electronic.
# Maxwell - invent - method
# Sentence: Henry Bessemer patents the Bessemer process for making steel, with improvements made by others over the following years.
# Bessemer - patent - process
# Sentence: James Harrison produces the world's first practical ice making machine and refrigerator using the principle of vapour compression in Geelong, Australia.
# Harrison - produce - machine
# Sentence: William Henry Perkin invents Mauveine, the first synthetic dye.
# Perkin - invent - Mauveine
# Sentence: Heinrich Geissler invents the Geissler tube.
# Geissler - invent - tube
# Sentence: Gaston Planté invents the lead acid battery, the first rechargeable battery.
# Planté - invent - battery
# Sentence: Joseph Swan produces carbon fibers.
# Swan - produce - fibers
# Sentence: Louis Pasteur invents the pasteurization process.
# Pasteur - invent - process
# Sentence: Carl Wilhelm Siemens and Pierre-Émile Martin invented the Siemens-Martin process for making steel.
# Martin - invent - process
# Sentence: Gregor Mendel publishes 'Versuche über Pflanzenhybriden' ("Experiments on Plant Hybridization"), effectively founding the science of genetics, though the importance of his work would not be appreciated until later on.
# Mendel - publish - Experiments
# Sentence: Alfred Nobel invents Dynamite, the first safely manageable explosive stronger than black powder.
# Nobel - invent - Dynamite
# Sentence: Lucien B. Smith invents barbed wire, which Joseph F. Glidden will modify in 1874, leading to the taming of the West and the end of the cowboys.
# Smith - invent - wire
# Sentence: J.E.T. Woods and J. Clark invented Stainless steel.
# Woods - invent - steel
# Sentence: Frederick Ransome invents the rotary kiln.
# Ransome - invent - kiln
# Sentence: Sir William Crookes, a chemist, invents the Crookes radiometer as the by-product of some chemical research.
# Crookes - invent - radiometer
# Sentence: Zénobe Gramme invents the first commercial electrical generator, the Gramme machine.
# Gramme - invent - generator
# Sentence: Nikolaus August Otto invents the Four-stroke cycle.
# Otto - invent - cycle
# Sentence: Alexander Graham Bell has a patent granted for the telephone.
# Bell - have - patent
# Sentence: Thomas Edison invents the first working phonograph.
# Edison - invent - phonograph
# Sentence: Lester Allan Pelton invents the Pelton wheel.
# Pelton - invent - wheel
# Sentence: Swan's, which he had been working on his since the 1860s, had a low resistance so was only suited for small installations.
# Swan - have - resistance
# Sentence: Edison designed a high-resistance bulb as part of a large-scale commercial electric lighting utility.
# Edison - design - bulb
# Sentence: Nikolay Benardos presents carbon arc welding, the first practical arc welding method.
# Benardos - present - method
# Sentence: Hiram Maxim invents the recoil-operated Maxim gun, ushering in the age of semi- and fully automatic firearms.
# Maxim - invent - gun
# Sentence: Paul Vieille invents Poudre B, the first smokeless powder for firearms.
# Vieille - invent - B
# Sentence: Sir Charles Parsons invents the modern steam turbine.
# Parsons - invent - turbine
# Sentence: John Kemp Starley invents the modern bicycle.
# Starley - invent - bicycle
# Sentence: Carl Gassner invents the zinc-carbon battery, the first dry cell battery, making portable electronics practical.
# Gassner - invent - battery
# Sentence: Charles Martin Hall and independently Paul Héroult invent the Hall–Héroult process for economically producing aluminum in 1886.Karl Benz invents the first petrol or gasoline powered auto-mobile (car).Carl Josef Bayer invents the Bayer process for the production of alumina.
# Hall - invent - Hall
# Sentence: James Blyth invents the first wind turbine used for generating electricity.
# Blyth - invent - turbine
# Sentence: John Stewart MacArthur, working in collaboration with brothers Dr. Robert and Dr. William Forrest develops the process of gold cyanidation.
# Robert - develop - process
# Sentence: John J. Loud invents the ballpoint pen.
# Loud - invent - pen
# Sentence: Heinrich Hertz publishes a conclusive proof of James Clerk Maxwell's electromagnetic theory in experiments that also demonstrate the existence of radio waves.
# Hertz - publish - proof
# Sentence: Frédéric Swarts invents the first chlorofluorocarbons to be applied as refrigerant.
# Swarts - invent - chlorofluorocarbons
# Sentence: Clément Ader invents the first aircraft, airplane, fly machine called Eole (aircraft) or Ader ÉoleWhitcomb Judson invents the zipper.
# Ader - invent - aircraft
# Sentence: Léon Bouly invents the cinematograph.
# Bouly - invent - cinematograph
# Sentence: Rudolf Diesel invents the diesel engine (although Herbert Akroyd Stuart had experimented with compression ignition before Diesel).Guglielmo Marconi invents a system of wireless communication using radio waves.
# Diesel - invent - engine
# Sentence: Wilhelm Conrad Röntgen invented the first radiograph (xrays).Hans von Pechmann synthesizes polyethylene, now the most common plastic in the world.
# Röntgen - invent - radiograph
# Sentence: Waldemar Jungner invents the nickel– battery.
# Jungner - invent - nickel
# Volta - invent - pile
# Davy - invent - lamp
# Trevithick - invent - locomotive
# Seishū - create - anesthetic
# Niépce - invent - engine
# Rivaz - design - automobile
# Fulton - expand - transportation
# Appert - invent - process
# Koenig - invent - press
# Clanny - pioneer - invention
# Fox - invent - machine
# Ronalds - build - telegraph
# Stirling - invent - engine
# Drais - invent - horse
# Brunel - invent - shield
# Blanchard - invent - lathe
# lathe - copy - shapes
# Niépce - invent - Heliography
# Döbereiner - invent - lighter
# Dreyse - invent - rifle
# Sturgeon - invent - electromagnet
# Walker - invent - match
# Neilson - develop - process
# Bell - invent - machine
# Jedlik - invent - machine
# Mann - invent - compressor
# Budding - invent - mower
# Faraday - invent - method
# Jacobi - invent - motor
# Henry - invent - relay
# Morse - invent - code
# Otis - invent - shovel
# Nasmyth - invent - hammer
# Becquerel - invent - method
# Bain - devise - telegraph
# Grove - invent - cell
# invents - superphosphate - fertilizer
# Johnson - invent - cement
# Maus - invent - machine
# Couch - invent - drill
# Hunt - invent - rifle
# Francis - invent - turbine
# Armstrong - invent - accumulator
# Otis - invent - elevator
# invents - reinforce - concrete
# Maxwell - invent - method
# Bessemer - patent - process
# Harrison - produce - machine
# Perkin - invent - Mauveine
# Geissler - invent - tube
# Planté - invent - battery
# Swan - produce - fibers
# Pasteur - invent - process
# Martin - invent - process
# Mendel - publish - Experiments
# Nobel - invent - Dynamite
# Smith - invent - wire
# Woods - invent - steel
# Ransome - invent - kiln
# Crookes - invent - radiometer
# Gramme - invent - generator
# Otto - invent - cycle
# Bell - have - patent
# Edison - invent - phonograph
# Pelton - invent - wheel
# Swan - have - resistance
# Edison - design - bulb
# Benardos - present - method
# Maxim - invent - gun
# Vieille - invent - B
# Parsons - invent - turbine
# Starley - invent - bicycle
# Gassner - invent - battery
# Hall - invent - Hall
# Blyth - invent - turbine
# Robert - develop - process
# Loud - invent - pen
# Hertz - publish - proof
# Swarts - invent - chlorofluorocarbons
# Ader - invent - aircraft
# Bouly - invent - cinematograph
# Diesel - invent - engine
# Röntgen - invent - radiograph
# Jungner - invent - nickel

# %% [markdown]
# ### <font color='red'>The code below is the same as the one above. How will you extend it to improve the extracted triples? For example, can you try to extract full names of people (rather than just their last names)?</font>

# %%
triples = []

for sent in sents_list:
    doc = nlp(sent)
    for token in doc:
        # For now, assume that the root of the tree is the predicate
        if token.dep_ == 'ROOT':
            t = Triple()
            # Store the lemmatised form (to normalise)
            t.predicate = token.lemma_
            dependents = token.children
            for d in dependents:
                if d.dep_ == 'dobj':
                    t.arg2 = d.text
                elif d.dep_ == 'nsubj':
                    t.arg1 = d.text
            if t.arg1 != '' and t.arg2 != '':
                print('Sentence:', sent)
                print(t.arg1, '-', t.predicate, '-', t.arg2)
                triples.append(t)

for t in triples:
    print(t.arg1, '-', t.predicate, '-', t.arg2)
# Out:
# Sentence: Alessandro Volta invents the voltaic pile, an early form of battery in Italy, based on previous works by Luigi Galvani.
# Volta - invent - pile
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Davy - invent - lamp
# Sentence: Richard Trevithick invents the steam locomotive.
# Trevithick - invent - locomotive
# Sentence: Hanaoka Seishū creates tsūsensan, the first modern general anesthetic.
# Seishū - create - anesthetic
# Sentence: Nicéphore Niépce invents the first internal combustion engine capable of doing useful work.
# Niépce - invent - engine
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# Rivaz - design - automobile
# Sentence: Robert Fulton expands water transportation and trade with the workable steamboat.
# Fulton - expand - transportation
# Sentence: Nicolas Appert invents the canning process for food.
# Appert - invent - process
# Sentence: Friedrich Koenig invents the first powered printing press, which was also the first to use a cylinder.
# Koenig - invent - press
# Sentence: William Reid Clanny pioneered the invention of the safety lamp which he improved in later years.
# Clanny - pioneer - invention
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# Fox - invent - machine
# Sentence: Francis Ronalds builds the first working electric telegraph using electrostatic means.
# Ronalds - build - telegraph
# Sentence: Robert Stirling invents the Stirling engine.
# Stirling - invent - engine
# Sentence: Baron Karl von Drais invents the dandy horse, an early velocipede and precursor to the modern bicycle.
# Drais - invent - horse
# Sentence: Marc Isambard Brunel invents the tunnelling shield.
# Brunel - invent - shield
# Sentence: Thomas Blanchard invents the pattern-tracing lathe (actually more like a shaper) and was completed by for the U.S. Ordnance Dept.
# Blanchard - invent - lathe
# Sentence: The lathe can copy symmetrical shapes and is used for making gun stocks, and later, ax handles.
# lathe - copy - shapes
# Sentence: Nicéphore Niépce invents Heliography, the first photographic process.
# Niépce - invent - Heliography
# Sentence: Johann Wolfgang Döbereiner invents the first lighter.
# Döbereiner - invent - lighter
# Sentence: Johann Nikolaus von Dreyse invents the bolt-action rifle.
# Dreyse - invent - rifle
# Sentence: William Sturgeon invents the electromagnet.
# Sturgeon - invent - electromagnet
# Sentence: John Walker invents the friction match.
# Walker - invent - match
# Sentence: James Beaumont Neilson develops the hot blast process.
# Neilson - develop - process
# Sentence: Patrick Bell invents the reaping machine.
# Bell - invent - machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Jedlik - invent - machine
# Sentence: William Mann invents the compound air compressor.
# Mann - invent - compressor
# Sentence: Edwin Budding invents the lawn mower.
# Budding - invent - mower
# Sentence: Michael Faraday invents a method of electromagnetic induction.
# Faraday - invent - method
# Sentence: Moritz von Jacobi, a German-born Russian, invents the first practical electric motor.
# Jacobi - invent - motor
# Sentence: Joseph Henry invents the electromechanical relay.
# Henry - invent - relay
# Sentence: Samuel Morse invents Morse code.
# Morse - invent - code
# Sentence: William Otis invents the steam shovel.
# Otis - invent - shovel
# Sentence: James Nasmyth invents the steam hammer.
# Nasmyth - invent - hammer
# Sentence: Edmond Becquerel invents a method for the photovoltaic effect, effectively producing the first solar cell.
# Becquerel - invent - method
# Sentence: Alexander Bain devises a printing telegraph.
# Bain - devise - telegraph
# Sentence: William Robert Grove invents the first fuel cell.
# Grove - invent - cell
# Sentence: John Bennet Lawes invents superphosphate, the first man-made fertilizer.
# invents - superphosphate - fertilizer
# Sentence: Isaac Charles Johnson invents Modern Portland cement.
# Johnson - invent - cement
# Sentence: Henri-Joseph Maus invents the Tunnel boring machine.
# Maus - invent - machine
# Sentence: Jonathan J. Couch invents the pneumatic drill.
# Couch - invent - drill
# Sentence: Walter Hunt invents the first repeating rifle to use metallic cartridges (of his own design) and a spring-fed magazine.
# Hunt - invent - rifle
# Sentence: James B. Francis invents the Francis turbine.
# Francis - invent - turbine
# Sentence: Sir William Armstrong invents the hydraulic accumulator.
# Armstrong - invent - accumulator
# Sentence: Elisha Otis invents the safety brake elevator.
# Otis - invent - elevator
# Sentence: François Coignet invents reinforced concrete.
# invents - reinforce - concrete
# Sentence: James Clerk Maxwell invents the first practical method for color photography, whether chemical or electronic.
# Maxwell - invent - method
# Sentence: Henry Bessemer patents the Bessemer process for making steel, with improvements made by others over the following years.
# Bessemer - patent - process
# Sentence: James Harrison produces the world's first practical ice making machine and refrigerator using the principle of vapour compression in Geelong, Australia.
# Harrison - produce - machine
# Sentence: William Henry Perkin invents Mauveine, the first synthetic dye.
# Perkin - invent - Mauveine
# Sentence: Heinrich Geissler invents the Geissler tube.
# Geissler - invent - tube
# Sentence: Gaston Planté invents the lead acid battery, the first rechargeable battery.
# Planté - invent - battery
# Sentence: Joseph Swan produces carbon fibers.
# Swan - produce - fibers
# Sentence: Louis Pasteur invents the pasteurization process.
# Pasteur - invent - process
# Sentence: Carl Wilhelm Siemens and Pierre-Émile Martin invented the Siemens-Martin process for making steel.
# Martin - invent - process
# Sentence: Gregor Mendel publishes 'Versuche über Pflanzenhybriden' ("Experiments on Plant Hybridization"), effectively founding the science of genetics, though the importance of his work would not be appreciated until later on.
# Mendel - publish - Experiments
# Sentence: Alfred Nobel invents Dynamite, the first safely manageable explosive stronger than black powder.
# Nobel - invent - Dynamite
# Sentence: Lucien B. Smith invents barbed wire, which Joseph F. Glidden will modify in 1874, leading to the taming of the West and the end of the cowboys.
# Smith - invent - wire
# Sentence: J.E.T. Woods and J. Clark invented Stainless steel.
# Woods - invent - steel
# Sentence: Frederick Ransome invents the rotary kiln.
# Ransome - invent - kiln
# Sentence: Sir William Crookes, a chemist, invents the Crookes radiometer as the by-product of some chemical research.
# Crookes - invent - radiometer
# Sentence: Zénobe Gramme invents the first commercial electrical generator, the Gramme machine.
# Gramme - invent - generator
# Sentence: Nikolaus August Otto invents the Four-stroke cycle.
# Otto - invent - cycle
# Sentence: Alexander Graham Bell has a patent granted for the telephone.
# Bell - have - patent
# Sentence: Thomas Edison invents the first working phonograph.
# Edison - invent - phonograph
# Sentence: Lester Allan Pelton invents the Pelton wheel.
# Pelton - invent - wheel
# Sentence: Swan's, which he had been working on his since the 1860s, had a low resistance so was only suited for small installations.
# Swan - have - resistance
# Sentence: Edison designed a high-resistance bulb as part of a large-scale commercial electric lighting utility.
# Edison - design - bulb
# Sentence: Nikolay Benardos presents carbon arc welding, the first practical arc welding method.
# Benardos - present - method
# Sentence: Hiram Maxim invents the recoil-operated Maxim gun, ushering in the age of semi- and fully automatic firearms.
# Maxim - invent - gun
# Sentence: Paul Vieille invents Poudre B, the first smokeless powder for firearms.
# Vieille - invent - B
# Sentence: Sir Charles Parsons invents the modern steam turbine.
# Parsons - invent - turbine
# Sentence: John Kemp Starley invents the modern bicycle.
# Starley - invent - bicycle
# Sentence: Carl Gassner invents the zinc-carbon battery, the first dry cell battery, making portable electronics practical.
# Gassner - invent - battery
# Sentence: Charles Martin Hall and independently Paul Héroult invent the Hall–Héroult process for economically producing aluminum in 1886.Karl Benz invents the first petrol or gasoline powered auto-mobile (car).Carl Josef Bayer invents the Bayer process for the production of alumina.
# Hall - invent - Hall
# Sentence: James Blyth invents the first wind turbine used for generating electricity.
# Blyth - invent - turbine
# Sentence: John Stewart MacArthur, working in collaboration with brothers Dr. Robert and Dr. William Forrest develops the process of gold cyanidation.
# Robert - develop - process
# Sentence: John J. Loud invents the ballpoint pen.
# Loud - invent - pen
# Sentence: Heinrich Hertz publishes a conclusive proof of James Clerk Maxwell's electromagnetic theory in experiments that also demonstrate the existence of radio waves.
# Hertz - publish - proof
# Sentence: Frédéric Swarts invents the first chlorofluorocarbons to be applied as refrigerant.
# Swarts - invent - chlorofluorocarbons
# Sentence: Clément Ader invents the first aircraft, airplane, fly machine called Eole (aircraft) or Ader ÉoleWhitcomb Judson invents the zipper.
# Ader - invent - aircraft
# Sentence: Léon Bouly invents the cinematograph.
# Bouly - invent - cinematograph
# Sentence: Rudolf Diesel invents the diesel engine (although Herbert Akroyd Stuart had experimented with compression ignition before Diesel).Guglielmo Marconi invents a system of wireless communication using radio waves.
# Diesel - invent - engine
# Sentence: Wilhelm Conrad Röntgen invented the first radiograph (xrays).Hans von Pechmann synthesizes polyethylene, now the most common plastic in the world.
# Röntgen - invent - radiograph
# Sentence: Waldemar Jungner invents the nickel– battery.
# Jungner - invent - nickel
# Volta - invent - pile
# Davy - invent - lamp
# Trevithick - invent - locomotive
# Seishū - create - anesthetic
# Niépce - invent - engine
# Rivaz - design - automobile
# Fulton - expand - transportation
# Appert - invent - process
# Koenig - invent - press
# Clanny - pioneer - invention
# Fox - invent - machine
# Ronalds - build - telegraph
# Stirling - invent - engine
# Drais - invent - horse
# Brunel - invent - shield
# Blanchard - invent - lathe
# lathe - copy - shapes
# Niépce - invent - Heliography
# Döbereiner - invent - lighter
# Dreyse - invent - rifle
# Sturgeon - invent - electromagnet
# Walker - invent - match
# Neilson - develop - process
# Bell - invent - machine
# Jedlik - invent - machine
# Mann - invent - compressor
# Budding - invent - mower
# Faraday - invent - method
# Jacobi - invent - motor
# Henry - invent - relay
# Morse - invent - code
# Otis - invent - shovel
# Nasmyth - invent - hammer
# Becquerel - invent - method
# Bain - devise - telegraph
# Grove - invent - cell
# invents - superphosphate - fertilizer
# Johnson - invent - cement
# Maus - invent - machine
# Couch - invent - drill
# Hunt - invent - rifle
# Francis - invent - turbine
# Armstrong - invent - accumulator
# Otis - invent - elevator
# invents - reinforce - concrete
# Maxwell - invent - method
# Bessemer - patent - process
# Harrison - produce - machine
# Perkin - invent - Mauveine
# Geissler - invent - tube
# Planté - invent - battery
# Swan - produce - fibers
# Pasteur - invent - process
# Martin - invent - process
# Mendel - publish - Experiments
# Nobel - invent - Dynamite
# Smith - invent - wire
# Woods - invent - steel
# Ransome - invent - kiln
# Crookes - invent - radiometer
# Gramme - invent - generator
# Otto - invent - cycle
# Bell - have - patent
# Edison - invent - phonograph
# Pelton - invent - wheel
# Swan - have - resistance
# Edison - design - bulb
# Benardos - present - method
# Maxim - invent - gun
# Vieille - invent - B
# Parsons - invent - turbine
# Starley - invent - bicycle
# Gassner - invent - battery
# Hall - invent - Hall
# Blyth - invent - turbine
# Robert - develop - process
# Loud - invent - pen
# Hertz - publish - proof
# Swarts - invent - chlorofluorocarbons
# Ader - invent - aircraft
# Bouly - invent - cinematograph
# Diesel - invent - engine
# Röntgen - invent - radiograph
# Jungner - invent - nickel

# %% [markdown]
# ### <font color='red'>Summarise below how you extended the code above to improve the extracted Open IE triples.</font>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## Comparison with the Stanford OpenIE tool

# %% [markdown]
# Stanford OpenIE is one of the more well-known Open Information Extraction tools.
# You can explore it in two ways:
# - by accessing the online demo at https://corenlp.run/ (under Annotations, keep only "openie"); this will take only one sentence at a time
# - by running the code below

# %%
# This might take a while
# !pip install stanford_openie
# Out:
# Requirement already satisfied: stanford_openie in /opt/anaconda3/lib/python3.8/site-packages (1.0.1)
# Requirement already satisfied: stanfordnlp in /opt/anaconda3/lib/python3.8/site-packages (from stanford_openie) (0.2.0)
# Requirement already satisfied: wget in /opt/anaconda3/lib/python3.8/site-packages (from stanford_openie) (3.2)
# Requirement already satisfied: torch>=1.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from stanfordnlp->stanford_openie) (1.7.1)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (from stanfordnlp->stanford_openie) (2.24.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.8/site-packages (from stanfordnlp->stanford_openie) (1.18.5)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.8/site-packages (from stanfordnlp->stanford_openie) (4.47.0)
# Requirement already satisfied: protobuf in /opt/anaconda3/lib/python3.8/site-packages (from stanfordnlp->stanford_openie) (3.14.0)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.8/site-packages (from torch>=1.0.0->stanfordnlp->stanford_openie) (3.7.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests->stanfordnlp->stanford_openie) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests->stanfordnlp->stanford_openie) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests->stanfordnlp->stanford_openie) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests->stanfordnlp->stanford_openie) (1.25.9)
# Requirement already satisfied: six>=1.9 in /opt/anaconda3/lib/python3.8/site-packages (from protobuf->stanfordnlp->stanford_openie) (1.15.0)

# %%
# This example might take long time when running for the first time. Please wait for it to be completed.
from openie import StanfordOpenIE

s_triples = []

with StanfordOpenIE() as client:
    # uncomment the following four lines if running on Google Colab!
    #import os
    #from stanfordnlp.server import CoreNLPClient
    #os.environ['CORENLP_HOME'] = str('/root/stanfordnlp_resources/stanford-corenlp-full-2018-10-05')
    #client.client = CoreNLPClient(annotators=['openie'], memory='8G', endpoint='http://localhost:9876')
    
    for sent in sents_list:
        stanford_triples = client.annotate(sent)
        for st in stanford_triples:
            s_triple = Triple()
            s_triple.arg1 = st['subject']
            s_triple.predicate = st['relation']
            s_triple.arg2 = st['object']
            print('Sentence:', sent)
            print(s_triple.arg1, '-', s_triple.predicate, '-', s_triple.arg2)
            s_triples.append(s_triple)

for st in s_triples:
    print(st.arg1, '-', st.predicate, '-', st.arg2)
# Out:
# Downloading to /Users/guohuanjie/stanfordnlp_resources.
#
# Extracting to /Users/guohuanjie/stanfordnlp_resources.
# Starting server with command: java -Xmx8G -cp /Users/guohuanjie/stanfordnlp_resources/stanford-corenlp-full-2018-10-05/* edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 60000 -threads 5 -maxCharLength 100000 -quiet True -serverProperties corenlp_server-d4c4a07f9d7a4717.props -preload openie
# Sentence: Alessandro Volta invents the voltaic pile, an early form of battery in Italy, based on previous works by Luigi Galvani.
# Alessandro Volta - invents - form
# Sentence: Alessandro Volta invents the voltaic pile, an early form of battery in Italy, based on previous works by Luigi Galvani.
# Alessandro Volta - invents - form in Italy
# Sentence: Alessandro Volta invents the voltaic pile, an early form of battery in Italy, based on previous works by Luigi Galvani.
# voltaic pile - form in - Italy
# Sentence: Alessandro Volta invents the voltaic pile, an early form of battery in Italy, based on previous works by Luigi Galvani.
# Alessandro Volta - invents - early form of battery
# Sentence: Alessandro Volta invents the voltaic pile, an early form of battery in Italy, based on previous works by Luigi Galvani.
# Alessandro Volta - invents - voltaic pile
# Sentence: Alessandro Volta invents the voltaic pile, an early form of battery in Italy, based on previous works by Luigi Galvani.
# Alessandro Volta - invents - pile
# Sentence: Alessandro Volta invents the voltaic pile, an early form of battery in Italy, based on previous works by Luigi Galvani.
# early form - is in - Italy
# Sentence: Alessandro Volta invents the voltaic pile, an early form of battery in Italy, based on previous works by Luigi Galvani.
# Alessandro Volta - invents - form of battery in Italy
# Sentence: Alessandro Volta invents the voltaic pile, an early form of battery in Italy, based on previous works by Luigi Galvani.
# previous works - based on pile is - early form of battery in Italy
# Sentence: Alessandro Volta invents the voltaic pile, an early form of battery in Italy, based on previous works by Luigi Galvani.
# Alessandro Volta - invents - early form of battery in Italy
# Sentence: Alessandro Volta invents the voltaic pile, an early form of battery in Italy, based on previous works by Luigi Galvani.
# Alessandro Volta - invents - early form in Italy
# Sentence: Alessandro Volta invents the voltaic pile, an early form of battery in Italy, based on previous works by Luigi Galvani.
# Alessandro Volta - invents - early form
# Sentence: Alessandro Volta invents the voltaic pile, an early form of battery in Italy, based on previous works by Luigi Galvani.
# Alessandro Volta - invents - form of battery
# Sentence: Alessandro Volta invents the voltaic pile, an early form of battery in Italy, based on previous works by Luigi Galvani.
# voltaic pile - form of - battery
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Humphry Davy - invents - exact date
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Humphry Davy - invents - arc lamp
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Humphry Davy - invents - date unclear
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Humphry Davy - invents - date
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Humphry Davy - invents - exact date unclear
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Friedrich Sertürner - discovers morphine as - active alkaloid extracted
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Friedrich Sertürner - discovers - morphine
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Friedrich Sertürner - discovers morphine as - first alkaloid extracted
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Friedrich Sertürner - discovers morphine as - first active alkaloid extracted from opium poppy plant
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Friedrich Sertürner - discovers morphine as - alkaloid
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Friedrich Sertürner - discovers morphine as - first alkaloid
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Friedrich Sertürner - discovers morphine as - alkaloid extracted
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Friedrich Sertürner - discovers morphine as - first active alkaloid
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Friedrich Sertürner - discovers morphine as - alkaloid extracted from opium poppy plant
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Friedrich Sertürner - discovers morphine as - first alkaloid extracted from opium poppy plant
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Friedrich Sertürner - discovers morphine as - active alkaloid
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Friedrich Sertürner - discovers morphine as - first active alkaloid extracted
# Sentence: Humphry Davy invents the arc lamp (exact date unclear; not practical as a light source until the invention of efficient electric generators).Friedrich Sertürner discovers morphine as the first active alkaloid extracted from the opium poppy plant.
# Friedrich Sertürner - discovers morphine as - active alkaloid extracted from opium poppy plant
# Sentence: Richard Trevithick invents the steam locomotive.
# Richard Trevithick - invents - steam locomotive
# Sentence: Hanaoka Seishū creates tsūsensan, the first modern general anesthetic.
# Hanaoka Seishū - creates - modern anesthetic
# Sentence: Hanaoka Seishū creates tsūsensan, the first modern general anesthetic.
# Hanaoka Seishū - creates - first general anesthetic
# Sentence: Hanaoka Seishū creates tsūsensan, the first modern general anesthetic.
# Hanaoka Seishū - creates - modern general anesthetic
# Sentence: Hanaoka Seishū creates tsūsensan, the first modern general anesthetic.
# Hanaoka Seishū - creates - general anesthetic
# Sentence: Hanaoka Seishū creates tsūsensan, the first modern general anesthetic.
# Hanaoka Seishū - creates - first modern general anesthetic
# Sentence: Hanaoka Seishū creates tsūsensan, the first modern general anesthetic.
# Hanaoka Seishū - creates - first modern anesthetic
# Sentence: Hanaoka Seishū creates tsūsensan, the first modern general anesthetic.
# Hanaoka Seishū - creates - tsūsensan
# Sentence: Hanaoka Seishū creates tsūsensan, the first modern general anesthetic.
# Hanaoka Seishū - creates - first anesthetic
# Sentence: Hanaoka Seishū creates tsūsensan, the first modern general anesthetic.
# Hanaoka Seishū - creates - anesthetic
# Sentence: Nicéphore Niépce invents the first internal combustion engine capable of doing useful work.
# Nicéphore Niépce - invents - combustion engine
# Sentence: Nicéphore Niépce invents the first internal combustion engine capable of doing useful work.
# Nicéphore Niépce - invents - internal combustion engine capable
# Sentence: Nicéphore Niépce invents the first internal combustion engine capable of doing useful work.
# Nicéphore Niépce - invents - first combustion engine
# Sentence: Nicéphore Niépce invents the first internal combustion engine capable of doing useful work.
# Nicéphore Niépce - invents - first combustion engine capable
# Sentence: Nicéphore Niépce invents the first internal combustion engine capable of doing useful work.
# Nicéphore Niépce - invents - combustion engine capable
# Sentence: Nicéphore Niépce invents the first internal combustion engine capable of doing useful work.
# Nicéphore Niépce - invents - first internal combustion engine capable
# Sentence: Nicéphore Niépce invents the first internal combustion engine capable of doing useful work.
# Nicéphore Niépce - invents - first internal combustion engine
# Sentence: Nicéphore Niépce invents the first internal combustion engine capable of doing useful work.
# Nicéphore Niépce - invents - internal combustion engine
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac de Rivaz - designs - first automobile
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac de Rivaz - designs - automobile powered by combustion engine
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac Rivaz - designs - automobile powered by internal combustion engine
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac de Rivaz - designs - first automobile powered by internal combustion engine fuelled
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac de Rivaz - designs - first automobile powered by combustion engine fuelled
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac Rivaz - designs - automobile powered
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac Rivaz - designs - automobile powered by internal combustion engine fuelled by hydrogen
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac de Rivaz - designs - automobile
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac de Rivaz - designs - first automobile powered by internal combustion engine
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac de Rivaz - designs - automobile powered by internal combustion engine fuelled
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac de Rivaz - designs - first automobile powered by internal combustion engine fuelled by hydrogen
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac de Rivaz - designs - first automobile powered
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac Rivaz - designs - first automobile powered by combustion engine fuelled
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac Rivaz - designs - first automobile powered by combustion engine fuelled by hydrogen
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac Rivaz - designs - first automobile powered
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac de Rivaz - designs - automobile powered by internal combustion engine fuelled by hydrogen
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac Rivaz - designs - automobile powered by combustion engine fuelled by hydrogen
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac Rivaz - designs - first automobile powered by internal combustion engine fuelled
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac de Rivaz - designs - first automobile powered by combustion engine fuelled by hydrogen
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac Rivaz - designs - automobile powered by internal combustion engine fuelled
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac Rivaz - designs - first automobile powered by internal combustion engine
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac de Rivaz - designs - automobile powered by combustion engine fuelled
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac de Rivaz - designs - automobile powered by internal combustion engine
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac Rivaz - designs - automobile powered by combustion engine fuelled
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac Rivaz - designs - automobile
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac de Rivaz - designs - first automobile powered by combustion engine
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac Rivaz - designs - first automobile
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac de Rivaz - designs - automobile powered
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac de Rivaz - designs - automobile powered by combustion engine fuelled by hydrogen
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac Rivaz - designs - first automobile powered by internal combustion engine fuelled by hydrogen
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac Rivaz - designs - automobile powered by combustion engine
# Sentence: François Isaac de Rivaz designs the first automobile powered by an internal combustion engine fuelled by hydrogen.
# François Isaac Rivaz - designs - first automobile powered by combustion engine
# Sentence: Robert Fulton expands water transportation and trade with the workable steamboat.
# Robert Fulton - expands trade with - steamboat
# Sentence: Robert Fulton expands water transportation and trade with the workable steamboat.
# Robert Fulton - expands water transportation with - workable steamboat
# Sentence: Robert Fulton expands water transportation and trade with the workable steamboat.
# Robert Fulton - expands - water transportation
# Sentence: Robert Fulton expands water transportation and trade with the workable steamboat.
# Robert Fulton - expands trade with - workable steamboat
# Sentence: Robert Fulton expands water transportation and trade with the workable steamboat.
# Robert Fulton - expands - trade
# Sentence: Robert Fulton expands water transportation and trade with the workable steamboat.
# Robert Fulton - expands water transportation with - steamboat
# Sentence: Nicolas Appert invents the canning process for food.
# Nicolas Appert - invents - canning process
# Sentence: Nicolas Appert invents the canning process for food.
# Nicolas Appert - invents - canning process for food
# Sentence: Friedrich Koenig invents the first powered printing press, which was also the first to use a cylinder.
# Friedrich Koenig - invents - printing press
# Sentence: Friedrich Koenig invents the first powered printing press, which was also the first to use a cylinder.
# Friedrich Koenig - invents - first powered printing press
# Sentence: Friedrich Koenig invents the first powered printing press, which was also the first to use a cylinder.
# Friedrich Koenig - invents - first printing press
# Sentence: Friedrich Koenig invents the first powered printing press, which was also the first to use a cylinder.
# Friedrich Koenig - invents - powered printing press
# Sentence: William Reid Clanny pioneered the invention of the safety lamp which he improved in later years.
# he - improved in - later years
# Sentence: William Reid Clanny pioneered the invention of the safety lamp which he improved in later years.
# William Reid Clanny - pioneered - invention
# Sentence: William Reid Clanny pioneered the invention of the safety lamp which he improved in later years.
# he - improved in - years
# Sentence: William Reid Clanny pioneered the invention of the safety lamp which he improved in later years.
# William Reid Clanny - pioneered - invention of safety lamp
# Sentence: Safety lamps based on Clanny's improved design were used until the adoption of electric lamps.
# Safety lamps - were - used
# Sentence: Safety lamps based on Clanny's improved design were used until the adoption of electric lamps.
# Clanny - on - improved design
# Sentence: Safety lamps based on Clanny's improved design were used until the adoption of electric lamps.
# Safety lamps - were used until - adoption of lamps
# Sentence: Safety lamps based on Clanny's improved design were used until the adoption of electric lamps.
# Safety lamps - were used until - adoption of electric lamps
# Sentence: Safety lamps based on Clanny's improved design were used until the adoption of electric lamps.
# Safety lamps - were used until - adoption
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# Matthew Murray - have - have credited at times with its invention
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# James Fox - invents planing machine - have also credited at times with its invention
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# James Fox - invents - modern planing machine
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# Matthew Murray - have - have also credited at times with its invention
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# James Fox - invents planing machine - have credited at times
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# Matthew Murray - have - have also credited with its invention
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# Matthew Murray - have - have also credited
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# Matthew Murray - have - have also credited at times
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# James Fox - invents planing machine - have credited at times with its invention
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# James Fox - invents planing machine - have also credited with its invention
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# Matthew Murray - have - have credited with its invention
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# James Fox - invents planing machine - have credited with its invention
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# James Fox - invents - planing machine
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# James Fox - invents planing machine - have also credited
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# Matthew Murray - have - have credited at times
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# James Fox - invents planing machine - have also credited at times
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# Matthew Murray - have - have credited
# Sentence: James Fox invents the modern planing machine, though Matthew Murray of Leeds and Richard Roberts of Manchester have also been credited at times with its invention.
# James Fox - invents planing machine - have credited
# Sentence: Francis Ronalds builds the first working electric telegraph using electrostatic means.
# Francis Ronalds - builds - first telegraph
# Sentence: Francis Ronalds builds the first working electric telegraph using electrostatic means.
# Francis Ronalds - builds - working telegraph
# Sentence: Francis Ronalds builds the first working electric telegraph using electrostatic means.
# Francis Ronalds - builds - first working telegraph
# Sentence: Francis Ronalds builds the first working electric telegraph using electrostatic means.
# Francis Ronalds - builds - first electric telegraph
# Sentence: Francis Ronalds builds the first working electric telegraph using electrostatic means.
# Francis Ronalds - builds - working electric telegraph
# Sentence: Francis Ronalds builds the first working electric telegraph using electrostatic means.
# Francis Ronalds - builds - telegraph
# Sentence: Francis Ronalds builds the first working electric telegraph using electrostatic means.
# Francis Ronalds - builds - electric telegraph
# Sentence: Francis Ronalds builds the first working electric telegraph using electrostatic means.
# Francis Ronalds - builds - first working electric telegraph
# Sentence: Robert Stirling invents the Stirling engine.
# Robert Stirling - invents - Stirling engine
# Sentence: Baron Karl von Drais invents the dandy horse, an early velocipede and precursor to the modern bicycle.
# Baron Karl von Drais - invents horse to - modern bicycle
# Sentence: Baron Karl von Drais invents the dandy horse, an early velocipede and precursor to the modern bicycle.
# Baron Karl von Drais - invents precursor to - bicycle
# Sentence: Baron Karl von Drais invents the dandy horse, an early velocipede and precursor to the modern bicycle.
# Baron Karl von Drais - invents precursor to - modern bicycle
# Sentence: Baron Karl von Drais invents the dandy horse, an early velocipede and precursor to the modern bicycle.
# Baron Karl von Drais - invents - velocipede
# Sentence: Baron Karl von Drais invents the dandy horse, an early velocipede and precursor to the modern bicycle.
# Baron Karl von Drais - invents - precursor
# Sentence: Baron Karl von Drais invents the dandy horse, an early velocipede and precursor to the modern bicycle.
# Baron Karl von Drais - invents - early velocipede
# Sentence: Baron Karl von Drais invents the dandy horse, an early velocipede and precursor to the modern bicycle.
# Baron Karl von Drais - invents velocipede to - bicycle
# Sentence: Baron Karl von Drais invents the dandy horse, an early velocipede and precursor to the modern bicycle.
# Baron Karl von Drais - invents - dandy horse
# Sentence: Baron Karl von Drais invents the dandy horse, an early velocipede and precursor to the modern bicycle.
# Baron Karl von Drais - invents horse to - bicycle
# Sentence: Baron Karl von Drais invents the dandy horse, an early velocipede and precursor to the modern bicycle.
# Baron Karl von Drais - invents - horse
# Sentence: Baron Karl von Drais invents the dandy horse, an early velocipede and precursor to the modern bicycle.
# Baron Karl von Drais - invents velocipede to - modern bicycle
# Sentence: Marc Isambard Brunel invents the tunnelling shield.
# Marc Isambard Brunel - invents - tunnelling shield
# Sentence: Thomas Blanchard invents the pattern-tracing lathe (actually more like a shaper) and was completed by for the U.S. Ordnance Dept.
# Thomas Blanchard - invents - actually shaper
# Sentence: Thomas Blanchard invents the pattern-tracing lathe (actually more like a shaper) and was completed by for the U.S. Ordnance Dept.
# Thomas Blanchard - invents - shaper
# Sentence: Thomas Blanchard invents the pattern-tracing lathe (actually more like a shaper) and was completed by for the U.S. Ordnance Dept.
# Thomas Blanchard - invents - more shaper
# Sentence: Thomas Blanchard invents the pattern-tracing lathe (actually more like a shaper) and was completed by for the U.S. Ordnance Dept.
# Thomas Blanchard - was completed by - by U.S. Ordnance Dept.
# Sentence: Thomas Blanchard invents the pattern-tracing lathe (actually more like a shaper) and was completed by for the U.S. Ordnance Dept.
# Thomas Blanchard - invents - actually more shaper
# Sentence: Thomas Blanchard invents the pattern-tracing lathe (actually more like a shaper) and was completed by for the U.S. Ordnance Dept.
# Thomas Blanchard - was - completed
# Sentence: The lathe can copy symmetrical shapes and is used for making gun stocks, and later, ax handles.
# lathe - can copy - symmetrical shapes
# Sentence: The lathe can copy symmetrical shapes and is used for making gun stocks, and later, ax handles.
# lathe - can copy - shapes
# Sentence: The lathe can copy symmetrical shapes and is used for making gun stocks, and later, ax handles.
# lathe - is - used
# Sentence: The lathe's patent is in force for 42 years, the record for any U.S. patent.
# lathe 's patent - is in - force for 42 years
# Sentence: The lathe's patent is in force for 42 years, the record for any U.S. patent.
# lathe 's patent - is in - force
# Sentence: The lathe's patent is in force for 42 years, the record for any U.S. patent.
# 42 years - for force is - record
# Sentence: The lathe's patent is in force for 42 years, the record for any U.S. patent.
# force - record for - U.S. patent
# Sentence: The lathe's patent is in force for 42 years, the record for any U.S. patent.
# lathe - has - patent
# Sentence: Nicéphore Niépce invents Heliography, the first photographic process.
# Nicéphore Niépce - invents - first photographic process
# Sentence: Nicéphore Niépce invents Heliography, the first photographic process.
# Nicéphore Niépce - invents - first process
# Sentence: Nicéphore Niépce invents Heliography, the first photographic process.
# Nicéphore Niépce - invents - process
# Sentence: Nicéphore Niépce invents Heliography, the first photographic process.
# Nicéphore Niépce - invents - Heliography
# Sentence: Nicéphore Niépce invents Heliography, the first photographic process.
# Nicéphore Niépce - invents - photographic process
# Sentence: Charles Babbage, considered the "father of the computer", begins building the first programmable mechanical computer.
# Charles Babbage - building - programmable computer
# Sentence: Charles Babbage, considered the "father of the computer", begins building the first programmable mechanical computer.
# Charles Babbage - building - first mechanical computer
# Sentence: Charles Babbage, considered the "father of the computer", begins building the first programmable mechanical computer.
# Charles Babbage - building - mechanical computer
# Sentence: Charles Babbage, considered the "father of the computer", begins building the first programmable mechanical computer.
# Charles Babbage - building - first programmable mechanical computer
# Sentence: Charles Babbage, considered the "father of the computer", begins building the first programmable mechanical computer.
# Charles Babbage - building - programmable mechanical computer
# Sentence: Charles Babbage, considered the "father of the computer", begins building the first programmable mechanical computer.
# Charles Babbage - building - first computer
# Sentence: Charles Babbage, considered the "father of the computer", begins building the first programmable mechanical computer.
# Charles Babbage - building - first programmable computer
# Sentence: Charles Babbage, considered the "father of the computer", begins building the first programmable mechanical computer.
# Charles Babbage - building - computer
# Sentence: Johann Wolfgang Döbereiner invents the first lighter.
# Johann Wolfgang Döbereiner - invents - first lighter
# Sentence: Johann Wolfgang Döbereiner invents the first lighter.
# Johann Wolfgang Döbereiner - invents - lighter
# Sentence: Johann Nikolaus von Dreyse invents the bolt-action rifle.
# Johann Nikolaus von Dreyse - invents - rifle
# Sentence: Johann Nikolaus von Dreyse invents the bolt-action rifle.
# Johann Nikolaus von Dreyse - invents - bolt-action rifle
# Sentence: William Sturgeon invents the electromagnet.
# William Sturgeon - invents - electromagnet
# Sentence: John Walker invents the friction match.
# John Walker - invents - friction match
# Sentence: James Beaumont Neilson develops the hot blast process.
# James Beaumont Neilson - develops - blast process
# Sentence: James Beaumont Neilson develops the hot blast process.
# James Beaumont Neilson - develops - hot blast process
# Sentence: Patrick Bell invents the reaping machine.
# Patrick Bell - invents - reaping machine
# Sentence: Patrick Bell invents the reaping machine.
# Patrick Bell - invents - machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# physicist Ányos Jedlik - invents - rotary electromechanical machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Hungarian physicist Ányos Jedlik - invents - commutated electromechanical machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Hungarian physicist Ányos Jedlik - invents machine with - electromagnets
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Hungarian physicist Ányos Jedlik - invents - first rotary machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# physicist Ányos Jedlik - invents - first rotary electromechanical machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Hungarian physicist Ányos Jedlik - invents - first commutated rotary electromechanical machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# physicist Ányos Jedlik - invents - first machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# physicist Ányos Jedlik - invents - first commutated rotary electromechanical machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# physicist Ányos Jedlik - invents - first commutated rotary machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Hungarian physicist Ányos Jedlik - invents - first rotary electromechanical machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Hungarian physicist Ányos Jedlik - invents - commutated rotary electromechanical machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# physicist Ányos Jedlik - invents - first commutated machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# physicist Ányos Jedlik - invents - machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Hungarian physicist Ányos Jedlik - invents - first commutated machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Hungarian physicist Ányos Jedlik - invents - first electromechanical machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Hungarian physicist Ányos Jedlik - invents - first commutated rotary machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# physicist Ányos Jedlik - invents - rotary machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Hungarian physicist Ányos Jedlik - invents - first commutated electromechanical machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Hungarian physicist Ányos Jedlik - invents - rotary machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# physicist Ányos Jedlik - invents - commutated machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# physicist Ányos Jedlik - invents - electromechanical machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Hungarian physicist Ányos Jedlik - invents - rotary electromechanical machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# physicist Ányos Jedlik - invents - first rotary machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# physicist Ányos Jedlik - invents - commutated rotary electromechanical machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Hungarian physicist Ányos Jedlik - invents - machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Hungarian physicist Ányos Jedlik - invents - commutated rotary machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Hungarian physicist Ányos Jedlik - invents - commutated machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# physicist Ányos Jedlik - invents - first electromechanical machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Hungarian physicist Ányos Jedlik - invents - electromechanical machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# physicist Ányos Jedlik - invents - first commutated electromechanical machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# Hungarian physicist Ányos Jedlik - invents - first machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# physicist Ányos Jedlik - invents - commutated electromechanical machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# physicist Ányos Jedlik - invents - commutated rotary machine
# Sentence: Hungarian physicist Ányos Jedlik invents the first commutated rotary electromechanical machine with electromagnets.
# physicist Ányos Jedlik - invents machine with - electromagnets
# Sentence: William Mann invents the compound air compressor.
# William Mann - invents - compound air compressor
# Sentence: Edwin Budding invents the lawn mower.
# Edwin Budding - invents - lawn mower
# Sentence: Michael Faraday invents a method of electromagnetic induction.
# Michael Faraday - invents - method of electromagnetic induction
# Sentence: Michael Faraday invents a method of electromagnetic induction.
# Michael Faraday - invents - method of induction
# Sentence: Michael Faraday invents a method of electromagnetic induction.
# Michael Faraday - invents - method
# Sentence: It would be independently invented by Joseph Henry the following year.
# It - would - would independently invented by Joseph Henry year
# Sentence: It would be independently invented by Joseph Henry the following year.
# It - would - would independently invented by Joseph Henry
# Sentence: It would be independently invented by Joseph Henry the following year.
# It - would - would invented
# Sentence: It would be independently invented by Joseph Henry the following year.
# It - would - would independently invented year
# Sentence: It would be independently invented by Joseph Henry the following year.
# It - would - would invented by Joseph Henry
# Sentence: It would be independently invented by Joseph Henry the following year.
# It - would - would invented by Joseph Henry following year
# Sentence: It would be independently invented by Joseph Henry the following year.
# It - would - would independently invented
# Sentence: It would be independently invented by Joseph Henry the following year.
# It - would - would invented following year
# Sentence: It would be independently invented by Joseph Henry the following year.
# It - would - would invented year
# Sentence: It would be independently invented by Joseph Henry the following year.
# It - would - would independently invented following year
# Sentence: It would be independently invented by Joseph Henry the following year.
# It - would - would invented by Joseph Henry year
# Sentence: It would be independently invented by Joseph Henry the following year.
# It - would - would independently invented by Joseph Henry following year
# Sentence: Moritz von Jacobi, a German-born Russian, invents the first practical electric motor.
# Moritz von Jacobi - invents - motor
# Sentence: Moritz von Jacobi, a German-born Russian, invents the first practical electric motor.
# Moritz von Jacobi - invents - first motor
# Sentence: Moritz von Jacobi, a German-born Russian, invents the first practical electric motor.
# Moritz von Jacobi - invents - practical electric motor
# Sentence: Moritz von Jacobi, a German-born Russian, invents the first practical electric motor.
# Moritz von Jacobi - invents - first practical electric motor
# Sentence: Moritz von Jacobi, a German-born Russian, invents the first practical electric motor.
# Moritz von Jacobi - invents - first practical motor
# Sentence: Moritz von Jacobi, a German-born Russian, invents the first practical electric motor.
# Moritz von Jacobi - invents - first electric motor
# Sentence: Moritz von Jacobi, a German-born Russian, invents the first practical electric motor.
# Moritz von Jacobi - invents - electric motor
# Sentence: Moritz von Jacobi, a German-born Russian, invents the first practical electric motor.
# Moritz von Jacobi - invents - practical motor
# Sentence: Joseph Henry invents the electromechanical relay.
# Joseph Henry - invents - electromechanical relay
# Sentence: Joseph Henry invents the electromechanical relay.
# Joseph Henry - invents - relay
# Sentence: Samuel Morse invents Morse code.
# Samuel Morse - invents - Morse code
# Sentence: Moritz von Jacobi invents Electrotyping.
# Moritz von Jacobi - invents - Electrotyping
# Sentence: William Otis invents the steam shovel.
# William Otis - invents - steam shovel
# Sentence: James Nasmyth invents the steam hammer.
# James Nasmyth - invents - steam hammer
# Sentence: Edmond Becquerel invents a method for the photovoltaic effect, effectively producing the first solar cell.
# Edmond Becquerel - effectively producing - first cell
# Sentence: Edmond Becquerel invents a method for the photovoltaic effect, effectively producing the first solar cell.
# Edmond Becquerel - producing - first cell
# Sentence: Edmond Becquerel invents a method for the photovoltaic effect, effectively producing the first solar cell.
# Edmond Becquerel - producing - first solar cell
# Sentence: Edmond Becquerel invents a method for the photovoltaic effect, effectively producing the first solar cell.
# Edmond Becquerel - effectively producing - first solar cell
# Sentence: Edmond Becquerel invents a method for the photovoltaic effect, effectively producing the first solar cell.
# Edmond Becquerel - invents - method for photovoltaic effect
# Sentence: Edmond Becquerel invents a method for the photovoltaic effect, effectively producing the first solar cell.
# Edmond Becquerel - invents - method for effect
# Sentence: Edmond Becquerel invents a method for the photovoltaic effect, effectively producing the first solar cell.
# Edmond Becquerel - invents - method
# Sentence: Edmond Becquerel invents a method for the photovoltaic effect, effectively producing the first solar cell.
# Edmond Becquerel - producing - cell
# Sentence: Edmond Becquerel invents a method for the photovoltaic effect, effectively producing the first solar cell.
# Edmond Becquerel - effectively producing - cell
# Sentence: Edmond Becquerel invents a method for the photovoltaic effect, effectively producing the first solar cell.
# Edmond Becquerel - effectively producing - solar cell
# Sentence: Edmond Becquerel invents a method for the photovoltaic effect, effectively producing the first solar cell.
# Edmond Becquerel - producing - solar cell
# Sentence: Alexander Bain devises a printing telegraph.
# Alexander Bain - devises - printing telegraph
# Sentence: William Robert Grove invents the first fuel cell.
# William Robert Grove - invents - first fuel cell
# Sentence: William Robert Grove invents the first fuel cell.
# William Robert Grove - invents - fuel cell
# Sentence: John Bennet Lawes invents superphosphate, the first man-made fertilizer.
# John Bennet Lawes - invents - first man-made fertilizer
# Sentence: John Bennet Lawes invents superphosphate, the first man-made fertilizer.
# John Bennet Lawes - invents - fertilizer
# Sentence: John Bennet Lawes invents superphosphate, the first man-made fertilizer.
# John Bennet Lawes - invents - first fertilizer
# Sentence: John Bennet Lawes invents superphosphate, the first man-made fertilizer.
# John Bennet Lawes - invents - man-made fertilizer
# Sentence: John Bennet Lawes invents superphosphate, the first man-made fertilizer.
# John Bennet Lawes - invents - superphosphate
# Sentence: Friedrich Gottlob Keller and, independently, Charles Fenerty come up with the wood pulp method of paper production.
# Charles Fenerty - independently come up with - wood pulp method
# Sentence: Friedrich Gottlob Keller and, independently, Charles Fenerty come up with the wood pulp method of paper production.
# Charles Fenerty - come up with - wood pulp method of paper production
# Sentence: Friedrich Gottlob Keller and, independently, Charles Fenerty come up with the wood pulp method of paper production.
# Charles Fenerty - come up with - wood pulp method
# Sentence: Friedrich Gottlob Keller and, independently, Charles Fenerty come up with the wood pulp method of paper production.
# Charles Fenerty - independently come up with - wood pulp method of paper production
# Sentence: Isaac Charles Johnson invents Modern Portland cement.
# Isaac Charles Johnson - invents - Modern Portland cement
# Sentence: Henri-Joseph Maus invents the Tunnel boring machine.
# Maus - invents - Tunnel machine
# Sentence: Henri-Joseph Maus invents the Tunnel boring machine.
# Henri-Joseph Maus - invents - Tunnel machine
# Sentence: Henri-Joseph Maus invents the Tunnel boring machine.
# Henri-Joseph Maus - invents - Tunnel boring machine
# Sentence: Henri-Joseph Maus invents the Tunnel boring machine.
# ...
# Robert Bunsen - is - first
# Robert Bunsen - use - chemical vapor deposition technique
# Elisha Otis - invents - safety brake elevator
# flight - using - dirigible
# manned flight - using - dirigible
# François Coignet - invents - concrete
# François Coignet - invents - reinforced concrete
# James Clerk Maxwell - invents - practical method for color photography
# James Clerk Maxwell - invents - first practical method for color photography
# James Clerk Maxwell - invents - first method for color photography
# James Clerk Maxwell - invents - method for color photography
# James Clerk Maxwell - invents - method
# James Clerk Maxwell - invents - practical method
# James Clerk Maxwell - invents - first practical method
# James Clerk Maxwell - invents - first method
# Bessemer process - is with - improvements made by others over following years
# world 's first practical ice - using - principle of vapour compression
# world 's first practical ice - using - principle
# world 's first ice - using - principle of vapour compression
# world 's ice - using principle in - Australia
# world 's ice - using - principle of vapour compression
# James Harrison - produces - world 's first ice
# world 's first ice - using principle in - Australia
# world 's first practical ice - using principle in - Australia
# world 's first ice - using principle in - Geelong
# world 's first ice - using - principle
# world 's practical ice - using - principle of vapour compression
# world 's ice - using - principle
# world 's ice - using principle in - Geelong
# James Harrison - produces - world 's first practical ice
# world 's first practical ice - using principle in - Geelong
# world 's practical ice - using principle in - Australia
# world 's practical ice - using - principle
# world 's practical ice - using principle in - Geelong
# world - has - first practical ice making
# James Harrison - produces - world 's ice
# James Harrison - produces - world 's practical ice
# William Henry Perkin - invents - first synthetic dye
# William Henry Perkin - invents - first dye
# William Henry Perkin - invents - synthetic dye
# William Henry Perkin - invents - dye
# William Henry Perkin - invents - Mauveine
# Heinrich Geissler - invents - Geissler tube
# Gaston Planté - invents - lead acid battery
# Gaston Planté - invents - battery
# Gaston Planté - invents - rechargeable battery
# Gaston Planté - invents - first rechargeable battery
# Gaston Planté - invents - first battery
# Gaston Planté - invents - acid battery
# Joseph Swan - produces - carbon fibers
# Alexander Parkes - invents - parkesine also known as celluloid
# Alexander Parkes - invents - first plastic
# Alexander Parkes - invents - man-made plastic
# Alexander Parkes - invents - first man-made plastic
# Alexander Parkes - invents - parkesine known
# Alexander Parkes - invents - parkesine known as celluloid
# Alexander Parkes - invents - parkesine also known
# Alexander Parkes - invents - parkesine
# Alexander Parkes - invents - plastic
# Louis Pasteur - invents - pasteurization process
# Pierre-Émile Martin - making - steel
# Carl Wilhelm Siemens - invented - Siemens-Martin process
# Pierre-Émile Martin - invented - Siemens-Martin process
# Gregor Mendel - effectively founding - science of genetics
# Gregor Mendel - founding - science
# Gregor Mendel - founding - science of genetics
# Gregor Mendel - effectively founding - science
# Alfred Nobel - invents - explosive stronger than black powder
# Alfred Nobel - invents - first manageable explosive stronger than black powder
# Alfred Nobel - invents - stronger
# Dynamite - first explosive stronger than - black powder
# Alfred Nobel - invents - stronger than powder
# Alfred Nobel - invents - safely manageable stronger than powder
# Dynamite - first manageable stronger than - black powder
# Dynamite - stronger than - black powder
# Dynamite - first stronger than - black powder
# Dynamite - first manageable explosive stronger than - powder
# Dynamite - first safely manageable explosive stronger than - black powder
# Dynamite - first manageable stronger than - powder
# Alfred Nobel - invents - first manageable stronger than powder
# Alfred Nobel - invents - first manageable explosive stronger
# Alfred Nobel - invents - explosive stronger than powder
# Alfred Nobel - invents - first manageable explosive stronger than powder
# Dynamite - first safely manageable explosive stronger than - powder
# Alfred Nobel - invents - Dynamite
# Dynamite - first safely manageable stronger than - black powder
# Dynamite - explosive stronger than - black powder
# Alfred Nobel - invents - safely manageable explosive stronger than powder
# Alfred Nobel - invents - first explosive stronger than black powder
# Alfred Nobel - invents - first safely manageable explosive stronger than powder
# Alfred Nobel - invents - first safely manageable explosive stronger than black powder
# Alfred Nobel - invents - first manageable stronger
# Dynamite - stronger than - black powder
# Alfred Nobel - invents - manageable explosive stronger
# Alfred Nobel - invents - manageable explosive stronger than powder
# Alfred Nobel - invents - safely manageable explosive stronger
# Dynamite - first safely manageable stronger than - powder
# Dynamite - first stronger than - powder
# Alfred Nobel - invents - first safely manageable explosive stronger
# Alfred Nobel - invents - first explosive stronger
# Dynamite - explosive stronger than - powder
# Dynamite - first explosive stronger than - powder
# Dynamite - first manageable explosive stronger than - black powder
# Alfred Nobel - invents - first explosive stronger than powder
# Dynamite - stronger than - powder
# Dynamite - manageable explosive stronger than - black powder
# Alfred Nobel - invents - manageable stronger
# Alfred Nobel - invents - explosive stronger
# Dynamite - safely manageable explosive stronger than - powder
# Dynamite - safely manageable explosive stronger than - black powder
# Alfred Nobel - invents - first manageable stronger than black powder
# Alfred Nobel - invents - first safely manageable stronger
# Alfred Nobel - invents - safely manageable explosive stronger than black powder
# Alfred Nobel - invents - stronger than black powder
# Dynamite - manageable stronger than - black powder
# Dynamite - manageable stronger than - powder
# Alfred Nobel - invents - manageable explosive stronger than black powder
# Dynamite - safely manageable stronger than - black powder
# Dynamite - manageable explosive stronger than - powder
# Alfred Nobel - invents - first safely manageable stronger than black powder
# Alfred Nobel - invents - first stronger than black powder
# Alfred Nobel - invents - safely manageable stronger
# Alfred Nobel - invents - safely manageable stronger than black powder
# Alfred Nobel - invents - first stronger
# Dynamite - safely manageable stronger than - powder
# Alfred Nobel - invents - first safely manageable stronger than powder
# Alfred Nobel - invents - manageable stronger than powder
# Alfred Nobel - invents - manageable stronger than black powder
# Alfred Nobel - invents - first stronger than powder
# Lucien B. Smith - invents - barbed wire leading to taming of West
# Lucien B. Smith - invents - wire leading to taming
# Lucien B. Smith - invents - wire leading
# Lucien B. Smith - invents - barbed wire leading to taming
# Joseph F. Glidden - will modify in - 1874
# Lucien B. Smith - invents - barbed wire
# Lucien B. Smith - invents - wire leading to taming of West
# Lucien B. Smith - invents - wire
# Lucien B. Smith - invents - barbed wire leading
# J.E.T. Woods - invented - steel
# J. Clark - invented - steel
# J. Clark - invented - Stainless steel
# J.E.T. Woods - invented - Stainless steel
# Harry Brearley - was - first
# Harry Brearley - commercialize - it
# Frederick Ransome - invents - rotary kiln
# Frederick Ransome - invents - kiln
# Sir William Crookes - invents - Crookes radiometer
# Sir William Crookes - invents Crookes radiometer as - by-product of chemical research
# Sir William Crookes - invents Crookes radiometer as - by-product
# Zénobe Gramme - invents - first commercial electrical generator
# Zénobe Gramme - invents - generator
# Zénobe Gramme - invents - first commercial generator
# Zénobe Gramme - invents - first generator
# Zénobe Gramme - invents - electrical generator
# Zénobe Gramme - invents - commercial generator
# Zénobe Gramme - invents - Gramme machine
# Zénobe Gramme - invents - first electrical generator
# Zénobe Gramme - invents - commercial electrical generator
# Gustave Trouvé - invents - first metal detector
# Gustave Trouvé - invents - metal detector
# Nikolaus August Otto - invents - cycle
# Nikolaus August Otto - invents - Four-stroke cycle
# Alexander Graham Bell - has - patent granted for telephone
# Alexander Graham Bell - has - patent granted
# Alexander Graham Bell - has - patent
# Bell - had worked on - development
# Bell - had worked on - development of telephone
# Thomas Edison - invents - working phonograph
# Thomas Edison - invents - first phonograph
# Thomas Edison - invents - phonograph
# Thomas Edison - invents - first working phonograph
# Henry Fleuss - is granted - patent
# Henry Fleuss - is granted - patent for first rebreather
# Henry Fleuss - is granted - patent for practical rebreather
# Henry Fleuss - is granted - patent for first practical rebreather
# Henry Fleuss - is granted - patent for rebreather
# Lester Allan Pelton - invents - Pelton wheel
# Joseph Swan - patent - Incandescent light bulb
# Thomas Edison - patent - light bulb
# Joseph Swan - patent - light bulb
# Thomas Edison - patent - Incandescent light bulb
# Joseph Swan - patent - functional light bulb
# Joseph Swan - patent - functional Incandescent light bulb
# Thomas Edison - patent - functional light bulb
# Thomas Edison - patent - functional Incandescent light bulb
# Swan - had - resistance
# Swan - had so - low resistance
# Swan - had so - resistance
# Swan - had - low resistance
# Edison - designed - high-resistance bulb
# Edison - designed - bulb
# Edison - designed bulb as - part of commercial lighting utility
# Edison - designed bulb as - part of large-scale commercial electric lighting utility
# Edison - designed bulb as - part of large-scale electric lighting utility
# Edison - designed bulb as - part of electric lighting utility
# Edison - designed bulb as - part
# Edison - designed bulb as - part of large-scale lighting utility
# Edison - designed bulb as - part of commercial electric lighting utility
# Edison - designed bulb as - part of large-scale commercial lighting utility
# Edison - designed bulb as - part of lighting utility
# Nikolay Benardos - presents - first arc welding method
# Nikolay Benardos - presents - practical arc welding method
# Nikolay Benardos - presents - carbon arc welding
# Nikolay Benardos - presents - first practical arc welding method
# Nikolay Benardos - presents - arc welding method
# firearms - ushering in - age of semi
# Hiram Maxim - invents - ushering firearms
# Hiram Maxim - invents - Maxim gun
# Hiram Maxim - invents - ushering in age firearms
# Hiram Maxim - invents - firearms
# Hiram Maxim - invents - recoil-operated Maxim gun
# Hiram Maxim - invents - ushering in age of semi firearms
# firearms - ushering in - age
# Paul Vieille - invents - powder
# Paul Vieille - invents - smokeless powder for firearms
# Paul Vieille - invents - powder for firearms
# Paul Vieille - invents - first powder
# Paul Vieille - invents - first powder for firearms
# Poudre B - powder for - firearms
# Paul Vieille - invents - smokeless powder
# Paul Vieille - invents - first smokeless powder
# Paul Vieille - invents - first smokeless powder for firearms
# Paul Vieille - invents - Poudre B
# Sir Charles Parsons - invents - modern steam turbine
# Sir Charles Parsons - invents - steam turbine
# Hungarian engineers - intvent - core efficiency transformer
# Hungarian engineers - intvent - closed core high efficiency transformer
# engineers - intvent - AC parallel power distribution
# engineers - intvent - closed core efficiency transformer
# Hungarian engineers - intvent - closed core efficiency transformer
# engineers - intvent - AC power distribution
# Hungarian engineers - intvent - AC power distribution
# engineers - intvent - core efficiency transformer
# engineers - intvent - core high efficiency transformer
# Hungarian engineers - intvent - core high efficiency transformer
# engineers - intvent - closed core high efficiency transformer
# Hungarian engineers - intvent - AC parallel power distribution
# John Kemp Starley - invents - modern bicycle
# John Kemp Starley - invents - bicycle
# Carl Gassner - invents - battery
# Carl Gassner - invents - zinc-carbon battery making
# Carl Gassner - invents - battery making
# Carl Gassner - invents - zinc-carbon battery
# Carl Gassner - invents - first dry cell battery
# Carl Gassner - invents - dry cell battery
# Carl Gassner - invents - first cell battery
# Carl Gassner - invents - cell battery
# Héroult process - producing aluminum in - 1886
# Charles Martin Hall - invent - Hall
# Paul Héroult - invent - Hall
# process - economically producing aluminum in - 1886
# process - producing aluminum in - 1886
# process - economically producing - aluminum
# process - producing - aluminum
# Héroult process - economically producing aluminum in - 1886
# Héroult process - producing - aluminum
# Héroult process - economically producing - aluminum
# first petrol - powered - car
# gasoline - powered - auto-mobile
# first petrol - powered - auto-mobile
# gasoline - powered - car
# petrol - powered - car
# petrol - powered - auto-mobile
# Carl Josef Bayer - invents Bayer process for - production
# Carl Josef Bayer - invents - Bayer process
# Carl Josef Bayer - invents Bayer process for - production of alumina
# James Blyth - invents - first wind turbine
# James Blyth - invents - first wind turbine used
# James Blyth - invents - wind turbine used
# James Blyth - invents - wind turbine
# John Stewart MacArthur - develops - process of gold cyanidation
# John Stewart MacArthur - working in - collaboration brothers Dr. Robert
# John Stewart MacArthur - working in - collaboration
# collaboration - is with - brothers Dr. Robert
# John Stewart MacArthur - develops - process
# John J. Loud - invents - ballpoint pen
# John J. Loud - invents - pen
# Heinrich Hertz - publishes - proof in experiments
# conclusive proof - is in - experiments
# Heinrich Hertz - publishes - conclusive proof of James Clerk Maxwell 's electromagnetic theory in experiments
# Heinrich Hertz - publishes - conclusive proof in experiments
# Heinrich Hertz - publishes - proof of James Clerk Maxwell 's electromagnetic theory
# Heinrich Hertz - publishes - proof of James Clerk Maxwell 's electromagnetic theory in experiments
# Heinrich Hertz - publishes - conclusive proof of James Clerk Maxwell 's theory in experiments
# Heinrich Hertz - publishes - proof of James Clerk Maxwell 's theory
# James Clerk Maxwell - of - electromagnetic theory
# Heinrich Hertz - publishes - conclusive proof of James Clerk Maxwell 's electromagnetic theory
# Heinrich Hertz - publishes - conclusive proof
# Heinrich Hertz - publishes - conclusive proof of James Clerk Maxwell 's theory
# Heinrich Hertz - publishes - proof
# Heinrich Hertz - publishes - proof of James Clerk Maxwell 's theory in experiments
# effects - had - had observed by people
# effects - had - had observed by people before
# effects - had - had observed by many people
# effects - had - had observed by many people before
# chlorofluorocarbons - be applied as - refrigerant
# first chlorofluorocarbons - be applied as - refrigerant
# chlorofluorocarbons - be - applied
# first chlorofluorocarbons - be - applied
# Frédéric Swarts - invents - chlorofluorocarbons
# Frédéric Swarts - invents - first chlorofluorocarbons
# first aircraft - fly - machine called
# Clément Ader invents - invents - zipper
# aircraft - fly - machine
# first aircraft - fly - machine
# aircraft - fly - machine called
# Léon Bouly - invents - cinematograph
# Rudolf Diesel - invents - diesel engine
# Guglielmo Marconi - invents - system
# Guglielmo Marconi - invents - system of wireless communication
# system - using - radio waves
# Guglielmo Marconi - invents - system of communication
# Wilhelm Conrad Röntgen - invented - radiograph
# Wilhelm Conrad Röntgen - invented - xrays
# Wilhelm Conrad Röntgen - invented - first radiograph
# common plastic - is in - world
# Hans von Pechmann - synthesizes - polyethylene
# Waldemar Jungner - invents - nickel

# %% [markdown]
# ### <font color='red'>Compare the triples you have been able to extract using your own code, with those extracted by Stanford OpenIE. What are the strong points and weaknesses of your own implementation? What are those of Stanford OpenIE?</font>
# <font color='red'><b>Your own implementation</b></font><br>
# <font color='red'>Strengths:</font><br>
# <font color='red'>Weaknesses:</font><br><br>
# <font color='red'><b>Stanford OpenIE</b></font><br>
# <font color='red'>Strengths:</font><br>
# <font color='red'>Weaknesses:</font><br>

# %% [markdown]
# ## Optional: Graph representation of knowledge extracted by Open IE

# %% [markdown]
# The code below builds a graph representation based on a list of triples extracted by Open IE.

# %%
# !pip install networkx
import networkx as nx

# Function for assigning unique IDs to arguments of triples
# Returns a dictionary of IDs and the corresponding argument names
def normalise_arguments(triples):
    global arg_id
    # arg_id below serves as the ID
    arg_id = 1
    argument_dict = dict()
    for triple in triples:
        argument_dict[triple.arg1] = arg_id
        arg_id += 1
        argument_dict[triple.arg2] = arg_id
        arg_id += 1
    return argument_dict
# Out:
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.8/site-packages (2.4)
# Requirement already satisfied: decorator>=4.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from networkx) (4.4.2)

# %%
# Function for generating the graph
from typing import List
# to_graph fuction was not called/used which will make the code below not running.
def to_graph(triples: List[Triple]) -> nx.Graph:
    global argument_dict
    argument_dict = normalise_arguments(triples)
    # Unlike arguments, predicates do not need to be unique
    predicate_id = arg_id
    graph = nx.Graph()
    for triple in triples:
        graph.add_node(argument_dict[triple.arg1], name=triple.arg1, type='subject')
        graph.add_node(predicate_id, name=triple.predicate, type='predicate')
        graph.add_node(argument_dict[triple.arg2], name=triple.arg2, type='object')
        graph.add_edge(argument_dict[triple.arg1], predicate_id)
        graph.add_edge(argument_dict[triple.arg2], predicate_id)
        predicate_id += 1
    return graph

# %% [markdown]
# The code below is for generating a visualisation of a given graph.

# %%
# !pip install pyvis
import os
import shutil
import tempfile
from pyvis.network import Network
from typing import List

class PyVisPrinter:
    """Class to visualise a (serialized) dataset entry."""

    def __init__(self, path=None):
        self.path = tempfile.mkdtemp(prefix='vis-', dir='/tmp') or path
        
    def clean(self):
        shutil.rmtree(self.path)

    def print_graph(self, graph: nx.Graph, filename):

        vis = Network(bgcolor="#222222",
                      width='100%',
                      font_color="white", notebook=True)
        
        for idx, (node, data) in enumerate(graph.nodes(data=True)):
            vis.add_node(
                node,
                title=data['name'],
                label=data['name'],
                color='yellow' if data['type'] == 'predicate' else 'green' if data['type'] == 'subject' else 'blue'
            )

        for i, (source, target) in enumerate(graph.edges()):
            if source in vis.get_nodes() and target in vis.get_nodes():
                vis.add_edge(source, target)
            else:
                self.logger.warning("source or target not in graph!")

        name = os.path.join(self.path, filename)
        return vis
# Out:
# Requirement already satisfied: pyvis in /opt/anaconda3/lib/python3.8/site-packages (0.1.8.2)
# Requirement already satisfied: networkx>=1.11 in /opt/anaconda3/lib/python3.8/site-packages (from pyvis) (2.4)
# Requirement already satisfied: jsonpickle>=1.4.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyvis) (2.0.0)
# Requirement already satisfied: jinja2>=2.9.6 in /opt/anaconda3/lib/python3.8/site-packages (from pyvis) (2.11.2)
# Requirement already satisfied: ipython>=5.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from pyvis) (7.16.1)
# Requirement already satisfied: decorator>=4.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from networkx>=1.11->pyvis) (4.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.8/site-packages (from jinja2>=2.9.6->pyvis) (1.1.1)
# Requirement already satisfied: jedi>=0.10 in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (0.17.1)
# Requirement already satisfied: pygments in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (2.6.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (3.0.5)
# Requirement already satisfied: setuptools>=18.5 in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (49.2.0.post20200714)
# Requirement already satisfied: backcall in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (4.3.3)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (0.1.0)
# Requirement already satisfied: pickleshare in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.10->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.8/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.3.0->pyvis) (0.6.0)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/lib/python3.8/site-packages (from traitlets>=4.2->ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from traitlets>=4.2->ipython>=5.3.0->pyvis) (1.15.0)

# %%
# Generate a graph based on a list of triples
graph = to_graph(triples)

# Generate an HTML file with the graph visualisation and display it
p = PyVisPrinter()
v = p.print_graph(graph, 'my_graph.html')
v.show('my_graph.html')
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="my_graph.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Below is a very basic way to query the graph.
# The code will return a tree traversed using depth-first search (DFS) with 'pen' as a starting point (answering the question "Who invented the pen?").
# Try other queries by changing the starting point (i.e., change 'pen' to 'Volta' to answer the question: "What did Volta invent?")

# %%
successors = nx.dfs_tree(graph, argument_dict['cinematograph'])
for s in successors:
    print (graph.nodes[s])
# Out:
# {'name': 'cinematograph', 'type': 'object'}
# {'name': 'invent', 'type': 'predicate'}
# {'name': 'Bouly', 'type': 'subject'}
